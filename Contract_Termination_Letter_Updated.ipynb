# %% [markdown]
# # AI-Powered Sentiment Analysis for Contracts
#
# ## **Objective**
# This project analyzes sentiment in contracts using **VADER Sentiment Analysis** and a **Bidirectional LSTM** model for classification. It explores contract tone, data augmentation techniques, and deep learning methods for improved sentiment classification.

# %% [markdown]
# #Installation

# %% [markdown]
# ## **Step 1: Install Required Libraries**
# Installing necessary Python libraries for NLP, sentiment analysis, and deep learning.

# %%
# %pip install vaderSentiment
# %pip install matplotlib
# %pip install beautifulsoup4
# %pip install ipython
# %pip install scikit-learn
# %pip install numpy
# %pip install textblob
# %pip install nltk
# %pip install keras-tuner
# %pip install tensorflow-hub
# %pip install Markdown
# %pip install scikit-optimize
# %pip install tensorflow==2.17.0 scikeras==0.11.0
# !pip install deep-translator
# !pip install keras_tuner
# !pip install emoji
# !pip install langdetect
# !pip install httpx==0.23.0
# !pip install googletrans
# !pip install transformers torch
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 1.5 MB/s eta 0:00:00
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=92da64e2eb32e4b272162ca245217bf4357aad9a16df9117ea80361097210704
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %% [markdown]
# ## **Step 2: Import Libraries & Setup**
# Import essential libraries for web scraping, text processing, and model training.

# %% [markdown]
# #Create Model

# %% [markdown]
# ## **Step 3: Download & Preprocess Data**
# Extract contract data from a legal contract website using `BeautifulSoup` and preprocess text.

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, ParameterSampler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve, f1_score
from sklearn.base import BaseEstimator, ClassifierMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import requests
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils.class_weight import compute_class_weight
import seaborn as sns
from collections import Counter
import time
from IPython.display import Markdown, display
import pandas as pd

# Download NLTK data
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# TensorFlow Configuration for GPU
gpus = tf.config.list_physical_devices('GPU')
if len(gpus) > 0:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# List of dataset URLs
urls = [
    "https://www.rocketlawyer.com/business-and-contracts/employers-and-hr/personnel-changes/document/notice-of-contract-termination?rlfr=srch:1:0&search_position=1&search_category=Documents&ampsearch_category_position=1&search_display=Notice+of+Contract+Termination&search_typed=contract+termination+letter"
]

# Text preprocessing function
def preprocess_text(text):
    text = BeautifulSoup(text, "html.parser").get_text()  # Convert HTML content to text
    text = re.sub(r'[^\w\s]', '', text)  # Remove non-word characters
    text = text.lower()  # Lowercase all characters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    tokens = word_tokenize(text)  # Tokenize the text
    stop_words = set(stopwords.words('english'))  # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatize
    return ' '.join(tokens)

# Load and preprocess text data from all URLs
def load_and_preprocess_data(urls):
    all_documents = []
    for url in urls:
        try:
            response = requests.get(url)
            response.encoding = "ISO-8859-1"
            soup = BeautifulSoup(response.text, "html.parser")
            text = soup.get_text()
            documents = text.split('. ')
            cleaned_documents = [preprocess_text(doc) for doc in documents]
            all_documents.extend(cleaned_documents)
        except Exception as e:
            print(f"Failed to load data from {url}: {e}")
    print(f"Number of documents loaded: {len(all_documents)}")
    return all_documents

# Load data from URLs
documents = load_and_preprocess_data(urls)

# Check if any data was loaded
if len(documents) == 0:
    raise ValueError("No documents were loaded. Please check the URLs and data extraction process.")

# Create balanced labels
half_size = len(documents) // 2
labels = np.array([0] * half_size + [1] * (len(documents) - half_size))

# Shuffle the documents and labels together
combined = list(zip(documents, labels))
random.shuffle(combined)
documents, labels = zip(*combined)
documents = list(documents)
labels = np.array(labels)

print(f"Class distribution before augmentation: {Counter(labels)}")

# Data Augmentation (example)
def synonym_augmentation(text):
    words = text.split()
    if not words:
        return text
    augmented_words = []
    for word in words:
        synonyms = wordnet.synsets(word)
        if synonyms:
            synonym = synonyms[0].lemmas()[0].name()
            if synonym != word:
                augmented_words.append(synonym)
            else:
                augmented_words.append(word)
        else:
            augmented_words.append(word)
    return ' '.join(augmented_words)

def random_insertion(text):
    words = text.split()
    if len(words) < 2:
        return text
    new_words = words.copy()
    for _ in range(3):
        add_word(new_words)
    return ' '.join(new_words)

def add_word(new_words):
    synonyms = []
    counter = 0
    while len(synonyms) < 1 and counter < 10:
        random_word = new_words[random.randint(0, len(new_words)-1)]
        synonyms = wordnet.synsets(random_word)
        counter += 1
    if synonyms:
        random_synonym = synonyms[0].lemmas()[0].name()
        new_words.insert(random.randint(0, len(new_words)-1), random_synonym)

# Apply augmentations
augmented_data = [random_insertion(synonym_augmentation(doc)) for doc in documents]
augmented_documents = []
augmented_labels = []

for doc, label in zip(augmented_data, labels):
    augmented_docs = [doc] * 90
    augmented_documents.extend(augmented_docs)
    augmented_labels.extend([label] * len(augmented_docs))

documents.extend(augmented_documents)
labels = np.concatenate((labels, augmented_labels))

print(f"Class distribution after augmentation: {Counter(labels)}")

# Split augmented data into train and test sets
train_data, test_data, train_labels, test_labels = train_test_split(
    documents, labels, test_size=0.2, random_state=42, stratify=labels
)

# Tokenization and padding
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(train_data)

X_train_seq = tokenizer.texts_to_sequences(train_data)
X_test_seq = tokenizer.texts_to_sequences(test_data)

max_len = 100
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# Convert to numpy arrays directly
X_train_final = np.array(X_train_pad)
y_train_final = np.array(train_labels)
X_test_pad = np.array(X_test_pad)
test_labels = np.array(test_labels)

# Compute class weights dynamically
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_final), y=y_train_final)
class_weights = dict(enumerate(class_weights))

# Define focal loss with adjusted parameters
def focal_loss(gamma=2.5, alpha=0.90):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        weights = alpha * y_true * tf.math.pow(1 - y_pred, gamma) + (1 - alpha) * (1 - y_true) * tf.math.pow(y_pred, gamma)
        loss = weights * cross_entropy
        return tf.reduce_mean(loss)
    return focal_loss_fixed

loss_fn = focal_loss(gamma=2.5, alpha=0.90)

# Define model creation function
def create_model(learning_rate=0.0001, lstm_units=16, dropout_rate=0.5):
    model = Sequential([
        Embedding(input_dim=5000, output_dim=128, input_length=max_len),
        BatchNormalization(),
        Bidirectional(LSTM(lstm_units, recurrent_dropout=0.5, kernel_regularizer=l2(0.0001))),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

# Define hyperparameters to tune with increased dropout rates
param_grid = {
    'learning_rate': [0.0001, 0.001],
    'lstm_units': [16, 32],
    'dropout_rate': [0.4, 0.5],  # Increased dropout rates
    'batch_size': [64, 128]
}

# Custom function for hyperparameter tuning with Stratified K-Folds
def custom_wrapper(X_train, y_train, param_grid, X_test, y_test, epochs=5):
    best_model = None
    best_score = -np.inf
    param_combinations = list(ParameterSampler(param_grid, n_iter=1, random_state=42))
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for params in param_combinations:
        print(f"Testing combination: {params}")
        fold_scores = []
        for train_index, val_index in skf.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = create_model(learning_rate=params['learning_rate'], lstm_units=params['lstm_units'], dropout_rate=params['dropout_rate'])
            start_time = time.time()
            history = model.fit(
                X_train_fold, y_train_fold,
                batch_size=params['batch_size'],
                epochs=epochs,
                validation_data=(X_val_fold, y_val_fold),
                verbose=1,
                class_weight=class_weights,
                callbacks = [
                    EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True),  # Decreased patience
                    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-5)  # Reduced patience
                ]


            )
            elapsed_time = time.time() - start_time
            print(f"Training time: {elapsed_time:.2f} seconds")
            val_score = model.evaluate(X_val_fold, y_val_fold, verbose=0)[1]
            fold_scores.append(val_score)

        avg_score = np.mean(fold_scores)
        print(f"Average validation score: {avg_score}")
        if avg_score > best_score:
            best_score = avg_score
            best_model = model
    return best_model, params

# Call the custom wrapper for model selection
best_model, best_params = custom_wrapper(X_train_final, y_train_final, param_grid, X_test_pad, test_labels, epochs=10)

print(f"Best Hyperparameters: {best_params}")

# Evaluate on the test set
test_loss, test_accuracy, test_auc = best_model.evaluate(X_test_pad, test_labels, verbose=0)
print(f"Test Accuracy: {test_accuracy}, Test AUC: {test_auc}")

# Predict test set with adjusted threshold
y_pred_prob = best_model.predict(X_test_pad)

# Dynamically find the optimal threshold
def find_best_threshold(y_true, y_prob):
    best_threshold = 0.5
    best_f1 = 0.0
    for threshold in np.arange(0.1, 0.9, 0.01):
        y_pred = (y_prob > threshold).astype(int)
        f1 = f1_score(y_true, y_pred)
        if f1 > best_f1:
            best_f1 = f1
            best_threshold = threshold
    return best_threshold, best_f1

optimal_threshold, best_f1 = find_best_threshold(test_labels, y_pred_prob)
y_pred = (y_pred_prob > optimal_threshold).astype("int32")

# Generate and print classification report and confusion matrix
print("Classification Report:")
print(classification_report(test_labels, y_pred, zero_division=1))
print("Confusion Matrix:")
conf_matrix = confusion_matrix(test_labels, y_pred)
print(conf_matrix)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Plot ROC curve
fpr, tpr, _ = roc_curve(test_labels, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Plot Precision-Recall curve
precision, recall, _ = precision_recall_curve(test_labels, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, lw=2, color='blue', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="upper right")
plt.show()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Number of documents loaded: 34
# Class distribution before augmentation: Counter({0: 17, 1: 17})
# Class distribution after augmentation: Counter({0: 1547, 1: 1547})
# Testing combination: {'lstm_units': 16, 'learning_rate': 0.0001, 'dropout_rate': 0.4, 'batch_size': 64}
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
# ...

# %% [markdown]
# ## **Step 4: Sentiment Analysis Using VADER**
# Calculate sentiment scores for contracts before model training.

# %% [markdown]
# #Sentiment of Training Data

# %% [markdown]
# ## **Step 5: Data Augmentation Techniques**
# Apply synonym replacement and random insertion to enhance training data.

# %%
analyzer = SentimentIntensityAnalyzer()
sentiment_scores_list = [analyzer.polarity_scores(doc) for doc in train_data]

# Aggregate results
average_scores = {
    'neg': sum(score['neg'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'neu': sum(score['neu'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'pos': sum(score['pos'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'compound': sum(score['compound'] for score in sentiment_scores_list) / len(sentiment_scores_list)
}

print("Average Sentiment Scores for train_data:")
print(average_scores)
# Out:
# Average Sentiment Scores for train_data:
# {'neg': 0.06315030303030296, 'neu': 0.7063761616161581, 'pos': 0.20054989898989922, 'compound': 0.3775764444444427}

# %% [markdown]
# ## **Step 6: Tokenization & Data Preparation**
# Convert text data into tokenized sequences and pad them for deep learning input.

# %% [markdown]
# #Sentiment of Test Data

# %% [markdown]
# ## **Step 7: Define & Train Deep Learning Model**
# Use a **Bidirectional LSTM model** with dropout and batch normalization for classification.

# %%
# Initialize Sentiment Analyzer
analyzer = SentimentIntensityAnalyzer()


sentiment_scores_list_test = [analyzer.polarity_scores(doc) for doc in test_data]

# Aggregate results
average_scores_test = {
    'neg': sum(score['neg'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'neu': sum(score['neu'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'pos': sum(score['pos'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'compound': sum(score['compound'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test)
}

print("Average Sentiment Scores for test_data:")
print(average_scores_test)
# Out:
# Average Sentiment Scores for test_data:
# {'neg': 0.06968659127625197, 'neu': 0.7047932148626823, 'pos': 0.19800969305331187, 'compound': 0.36554184168012893}

# %% [markdown]
# ## **Step 8: Model Evaluation**
# Evaluate the trained model using **accuracy, AUC, precision-recall, and confusion matrix**.

# %% [markdown]
# #Inject Positive Sentences on Training Data

# %% [markdown]
# ## **Step 9: Results & Interpretation**
# Visualize performance using plots like **ROC curve** and **confusion matrix**.

# %%
# List of 281 positive sentences contract termination letters
positive_sentences = [
    "We are grateful for the collaboration and value the opportunities this contract has brought.",
    "This termination marks the end of a successful chapter, and we look forward to new opportunities ahead.",
    "While the contract is ending, our respect for the quality of your work remains strong.",
    "This conclusion brings a chance to reflect on the positive outcomes of our agreement.",
    "We appreciate the professional relationship we've shared and the achievements we've reached together.",
    "This letter signifies the completion of our mutual goals under the contract.",
    "Your commitment during this contract has been truly remarkable, and we are grateful for your efforts.",
    "Ending this contract allows us to pursue future collaborations with fresh perspectives.",
    "We value the progress we've made together and look forward to potential future engagements.",
    "The contract's conclusion doesn't diminish the positive contributions made during our partnership.",
    "The termination of this contract provides an opportunity for growth and new endeavors.",
    "We appreciate your dedication throughout the duration of our agreement.",
    "Your team's professionalism and expertise have been key to our successful partnership.",
    "As we conclude this contract, we wish you continued success in your future projects.",
    "We are thankful for the milestones we have achieved together during this contract.",
    "This termination is a natural progression in our journey toward new goals.",
    "We are proud of the productive collaboration we've experienced under this agreement.",
    "The termination of the contract is a testament to the completion of our objectives.",
    "Your contributions have been essential, and we value the time spent working together.",
    "The conclusion of this contract allows us to explore new opportunities and partnerships.",
    "We are confident that both parties will find success beyond this contract.",
    "The work done under this agreement has set a strong foundation for future collaborations.",
    "Thank you for the positive impact you have made during the course of this contract.",
    "We look forward to staying in touch and possibly working together again in the future.",
    "Your dedication to quality has been instrumental in the success of this contract.",
    "While this contract is ending, our mutual respect and appreciation will endure.",
    "We are proud of what we have achieved together, and this termination is part of our growth.",
    "We remain enthusiastic about the possibilities that lie ahead for both parties.",
    "The end of this contract marks a new beginning for future collaborations.",
    "We have valued every step of our partnership and look forward to staying connected.",
    "Your excellent work has made a significant difference during this contract.",
    "As we conclude this contract, we reflect on the shared successes with gratitude.",
    "The progress we've made together under this contract has been truly remarkable.",
    "This contract termination provides space for both parties to innovate and grow.",
    "We appreciate your efforts and the professionalism shown throughout this agreement.",
    "We are proud of the work we have accomplished together under this contract.",
    "The termination of the contract allows us to transition to new, exciting opportunities.",
    "We celebrate the success of our collaboration as we part ways under this agreement.",
    "Thank you for your commitment and hard work during the entire term of this contract.",
    "This contract has strengthened our business relationship, and we look forward to future opportunities.",
    "Your contributions have been a cornerstone of our project's success, and we value your partnership.",
    "Though the contract is ending, the bonds we have built will continue to grow.",
    "Your dedication has been exceptional, and we appreciate your support throughout this partnership.",
    "We are thankful for the experience and look forward to exploring new possibilities with you.",
    "The contract may end, but our admiration for your work continues.",
    "The completion of this contract opens new doors for us both.",
    "We are excited about the future, and we hope to cross paths again in future projects.",
    "The goals we set together have been achieved with excellence, and we are grateful for your partnership.",
    "This contract termination reflects the natural conclusion of our shared objectives.",
    "We express our gratitude for your collaboration and the success we've built together.",
    "The professionalism shown throughout this contract has been outstanding, and we value the partnership.",
    "As we end this contract, we acknowledge the positive impact made on both sides.",
    "This agreement has been a great journey, and we appreciate your contributions to its success.",
    "We celebrate the achievements under this contract and are confident of future success for both sides.",
    "The completion of this contract brings new opportunities for innovation and collaboration.",
    "This termination allows us to reflect on the great work done and to explore new ventures.",
    "Your efforts throughout this contract have been exceptional, and we thank you for your contributions.",
    "The work completed under this agreement leaves a lasting positive impression on both parties.",
    "We conclude this contract with a sense of accomplishment and gratitude for your partnership.",
    "This termination provides an opportunity for us to pursue fresh challenges and possibilities.",
    "Your involvement has made a significant impact on the outcome of this contract.",
    "The positive outcomes of this agreement will benefit us both for years to come.",
    "We reflect on this contract with a sense of pride and accomplishment.",
    "Thank you for your ongoing support and dedication throughout this contract.",
    "We’ve valued every aspect of our partnership and hope to continue collaborating in the future.",
    "The termination of this contract signifies the successful completion of our goals.",
    "We’ve enjoyed working with you and appreciate the mutual success we’ve achieved.",
    "Your contribution to this contract has been significant, and we are thankful for your commitment.",
    "This contract’s end allows us to celebrate the positive achievements we’ve made together.",
    "The experience of working with you has been incredibly rewarding.",
    "We look forward to future opportunities that will allow us to collaborate once again.",
    "The successful completion of this contract is a testament to our shared dedication.",
    "We are thankful for the excellent work done under this agreement.",
    "The completion of this contract has been a positive experience for all involved.",
    "This termination marks the end of a chapter full of success and growth.",
    "Your contributions have been key to our accomplishments, and we thank you.",
    "We look back on this contract as a successful partnership that has benefited both sides.",
    "The experience we’ve gained from this contract will guide us in future projects.",
    "The positive results of this agreement reflect the strength of our collaboration.",
    "We’ve appreciated working with your team and value the results we’ve achieved together.",
    "The end of this contract presents an opportunity for us both to explore new directions.",
    "Thank you for being a reliable and professional partner throughout this agreement.",
    "The success we’ve achieved under this contract has been a result of our strong collaboration.",
    "We appreciate your commitment to excellence and the positive impact it has made on this contract.",
    "We end this contract on a positive note, with many successes to reflect upon.",
    "The achievements made during this contract will have a lasting positive impact.",
    "We are proud of what we’ve accomplished together and thank you for your efforts.",
    "Your dedication has made a big difference, and we are grateful for your contributions.",
    "This contract termination signifies the completion of our mutual goals, with great results.",
    "We’ve appreciated the professionalism and commitment you’ve shown throughout this agreement.",
    "The work done under this contract reflects the strong partnership we’ve built.",
    "The positive outcomes of this contract are a reflection of your excellent work.",
    "The end of this contract brings new opportunities for growth and continued success.",
    "We’re thankful for the collaboration and the value it has brought to our organization.",
    "Your contributions have made a meaningful difference, and we are grateful for your support.",
    "The conclusion of this contract represents the completion of an important phase for both of us.",
    "We are proud of the positive outcomes achieved under this agreement.",
    "The end of this contract presents opportunities for us to continue building on our success.",
    "Thank you for being such a dedicated partner throughout this contract.",
    "The work we’ve done together under this contract has set a strong foundation for future success.",
    "We appreciate the collaboration and the mutual benefits achieved through this agreement.",
    "This contract’s completion reflects the shared success of both parties.",
    "Your involvement has been a key factor in the success of this contract.",
    "We are proud of the achievements we’ve made together and look forward to new ventures.",
    "The termination of this contract provides space for new and exciting opportunities.",
    "Your team’s dedication has been critical to the success of this contract.",
    "The work accomplished under this contract is a testament to our strong collaboration.",
    "We are thankful for the positive outcomes of this partnership and the value it has brought.",
    "The end of this contract marks the beginning of new and exciting opportunities.",
    "Your professionalism and commitment to excellence have been greatly appreciated.",
    "We conclude this contract with a sense of pride in what we’ve achieved together.",
    "We are thankful for the positive experience of working together under this agreement.",
    "Your contributions have been integral to the success of this contract, and we appreciate your efforts.",
    "The conclusion of this contract opens the door to future collaborations and new possibilities.",
    "We are proud of the positive impact this contract has had and look forward to continued success.",
    "The success we’ve achieved under this agreement is a testament to your hard work and dedication.",
    "We are thankful for your contributions and look forward to future opportunities.",
    "The termination of this contract allows us to celebrate the achievements we’ve made together.",
    "We conclude this contract with a sense of gratitude for your partnership and hard work.",
    "Your dedication throughout this contract has been instrumental in our shared success.",
    "We appreciate the value you’ve added under this agreement and the positive impact it has had.",
    "The completion of this contract allows us to reflect on the achievements made together.",
    "Your commitment to excellence has been evident throughout the duration of this contract.",
    "We are proud of the progress we’ve made together under this agreement.",
    "The end of this contract is a positive milestone, marking the successful completion of our goals.",
    "We are grateful for the opportunity to have worked together and achieved such positive outcomes.",
    "The conclusion of this contract reflects the successful collaboration and shared dedication of both parties.",
    "We’ve appreciated the hard work and dedication you’ve shown throughout this agreement.",
    "The work we’ve done together under this contract will continue to have a positive impact moving forward.",
    "The achievements made during this contract are a result of our strong partnership and shared commitment.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this contract are a reflection of your hard work and dedication.",
    "We are thankful for the successful collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the success of this contract, and we appreciate your commitment.",
    "The completion of this contract provides an opportunity to reflect on the progress we’ve made together.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this contract.",
    "Your team’s commitment to excellence has been key to the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward."
]

# Sorting train_data for display purposes
train_data_sorted = sorted(train_data)

# Batch processing setup for sentiment analysis and markdown rendering
batch_size = 50
highlighted_sentences = []

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Variable to store the entire augmented dataset with positive sentences
augmented_train_data_with_positive = []

# Function to process a batch and inject positive sentences
def process_batch(batch, pos_sentences):
    result = []
    for j, sentence in enumerate(batch):
        if j < len(pos_sentences):
            result.append(f"**{pos_sentences[j % len(pos_sentences)]}**")  # Inject and highlight
        result.append(sentence)
    return result

# Initialize overall sentiment score tracking
overall_sentiment_scores = {'neg': 0, 'neu': 0, 'pos': 0, 'compound': 0}
total_batches = (len(train_data_sorted) // batch_size) + 1

# Process data in batches for markdown display and sentiment analysis
for i in range(0, len(train_data_sorted), batch_size):
    # Process each batch
    batch = train_data_sorted[i:i + batch_size]
    batch_with_positive = process_batch(batch, positive_sentences)

    # Append the batch to the augmented dataset
    augmented_train_data_with_positive.extend(batch_with_positive)

    # Join the current batch for sentiment analysis
    batch_text = '. '.join(batch_with_positive)

    # Perform sentiment analysis on the batch
    sentiment_scores = analyzer.polarity_scores(batch_text)

    # Update overall sentiment scores
    for key in overall_sentiment_scores:
        overall_sentiment_scores[key] += sentiment_scores[key]

    # Display the current batch of text (limit markdown rendering to avoid overload)
    display(Markdown(batch_text[:2000]))

# Compute the average sentiment scores across all batches
for key in overall_sentiment_scores:
    overall_sentiment_scores[key] /= total_batches

# Output overall sentiment scores after injecting positive sentences
print("Overall Sentiment Scores after injecting positive sentences:")
print("Negative:", overall_sentiment_scores['neg'])
print("Neutral:", overall_sentiment_scores['neu'])
print("Positive:", overall_sentiment_scores['pos'])
print("Compound:", overall_sentiment_scores['compound'])
# Out:
# **We are grateful for the collaboration and value the opportunities this contract has brought.**. . **This termination marks the end of a successful chapter, and we look forward to new opportunities ahead.**. . **While the contract is ending, our respect for the quality of your work remains strong.**. . **This conclusion brings a chance to reflect on the positive outcomes of our agreement.**. . **We appreciate the professional relationship we've shared and the achievements we've reached together.**. . **This letter signifies the completion of our mutual goals under the contract.**. . **Your commitment during this contract has been truly remarkable, and we are grateful for your efforts.**. . **Ending this contract allows us to pursue future collaborations with fresh perspectives.**. . **We value the progress we've made together and look forward to potential future engagements.**. . **The contract's conclusion doesn't diminish the positive contributions made during our partnership.**. 
# ...

# %% [markdown]
# #Inject Negative Sentences on Training Data

# %%
# List of 281 strongly negative sentences contract termination letters
negative_sentences = [
    "The termination of this contract reflects the numerous failures and disappointments throughout the collaboration.",
    "We regret to inform you that this contract has been terminated due to persistent underperformance.",
    "This contract's conclusion marks the end of an unsatisfactory partnership that consistently fell short of expectations.",
    "The termination has been prompted by your failure to meet the agreed-upon standards and deadlines.",
    "Your inability to fulfill your obligations has led to the termination of this contract.",
    "Despite numerous warnings, the lack of improvement has forced us to end this contract prematurely.",
    "The decision to terminate this contract was driven by the recurring issues and unresolved conflicts.",
    "We have been left with no choice but to terminate this contract due to your ongoing lack of cooperation.",
    "The termination reflects the complete breakdown of communication and trust between our teams.",
    "This contract has been terminated due to your repeated failure to adhere to the agreed-upon terms.",
    "The end of this contract is a direct result of your continuous failure to deliver satisfactory results.",
    "Your inability to meet the project’s deadlines and requirements has resulted in the termination of this contract.",
    "The persistent lack of professionalism throughout the duration of this contract has led to its termination.",
    "Due to your failure to comply with the agreed-upon standards, this contract has been terminated.",
    "The termination is a direct consequence of the numerous issues and delays caused by your team.",
    "We are terminating this contract due to the poor quality of work delivered over the course of the agreement.",
    "The termination of this contract is the result of your team's inability to meet our expectations.",
    "Repeated failures to communicate effectively have led to the termination of this contract.",
    "This contract has been terminated because of your failure to address critical issues in a timely manner.",
    "Your refusal to collaborate and work toward solutions has forced us to terminate this contract.",
    "The end of this contract is a reflection of your consistent inability to meet deadlines and standards.",
    "Your lack of transparency throughout this agreement has led to the termination of this contract.",
    "This contract has been terminated due to your failure to deliver the promised results.",
    "The termination reflects the dissatisfaction with the quality of work delivered by your team.",
    "The numerous delays and missed deadlines have resulted in the termination of this contract.",
    "Due to your team's incompetence and lack of professionalism, we have decided to terminate this contract.",
    "The contract's termination is a direct consequence of the repeated failure to deliver on key objectives.",
    "Your inability to address ongoing issues has led to the premature termination of this contract.",
    "We are terminating this contract due to your failure to meet even the most basic of requirements.",
    "The continuous lack of accountability has forced us to bring this contract to an end.",
    "This contract has been terminated due to your team's repeated failure to produce satisfactory work.",
    "The termination of this contract reflects your ongoing inability to meet the project's critical needs.",
    "Your failure to improve performance despite multiple warnings has resulted in the termination of this contract.",
    "This contract has been terminated due to the persistent issues and unresolved problems caused by your team.",
    "Your failure to meet our expectations has led to the premature termination of this contract.",
    "The termination reflects the lack of trust and confidence in your ability to deliver on promises.",
    "This contract has been terminated due to the significant delays and unaddressed issues throughout the project.",
    "Your lack of commitment to the project has resulted in the termination of this contract.",
    "Due to the consistent failure to deliver satisfactory work, we have been forced to terminate this contract.",
    "The termination of this contract is a reflection of your ongoing lack of professionalism and accountability.",
    "We have decided to terminate this contract due to your failure to adhere to the agreed-upon terms.",
    "The numerous unresolved issues and delays have led to the termination of this contract.",
    "This contract has been terminated due to your inability to meet even the most basic expectations.",
    "Your refusal to take responsibility for the project's failures has led to the termination of this contract.",
    "The persistent lack of communication has forced us to terminate this contract.",
    "Due to your continuous failure to deliver on promises, we have decided to terminate this contract.",
    "The termination of this contract reflects the numerous issues that have remained unresolved throughout the project.",
    "We are terminating this contract due to the unprofessional conduct displayed by your team.",
    "Your lack of commitment to resolving key issues has resulted in the termination of this contract.",
    "The end of this contract reflects the complete breakdown of trust and communication between our teams.",
    "The contract has been terminated due to your ongoing inability to meet deadlines and requirements.",
    "Your failure to address critical issues in a timely manner has led to the termination of this contract.",
    "This contract has been terminated because of the numerous delays and poor-quality work delivered by your team.",
    "The termination reflects the dissatisfaction with the overall progress of the project and your team's performance.",
    "Due to the lack of improvement in the quality of work, we have decided to terminate this contract.",
    "This contract has been terminated because of your continuous failure to meet agreed-upon standards.",
    "Your lack of professionalism and accountability has led to the termination of this contract.",
    "The decision to terminate this contract was driven by the numerous unresolved issues caused by your team.",
    "We are terminating this contract due to the poor communication and lack of transparency throughout the project.",
    "Your failure to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination of this contract reflects your inability to meet the project's critical needs.",
    "This contract has been terminated because of the significant delays and issues caused by your team.",
    "Your refusal to collaborate and work toward solutions has led to the premature termination of this contract.",
    "The persistent lack of professionalism displayed by your team has forced us to terminate this contract.",
    "Due to your team's incompetence and failure to meet deadlines, we have decided to terminate this contract.",
    "The termination of this contract is a direct result of your inability to meet our expectations.",
    "This contract has been terminated due to the ongoing issues and lack of progress made by your team.",
    "The numerous delays and missed deadlines have led to the termination of this contract.",
    "We are terminating this contract because of your failure to deliver satisfactory work on time.",
    "The decision to terminate this contract reflects the complete breakdown of communication and trust.",
    "Your team's lack of accountability has led to the termination of this contract.",
    "The termination of this contract is a result of your continuous failure to meet project requirements.",
    "Your inability to produce quality work has resulted in the termination of this contract.",
    "We have decided to terminate this contract due to your team's unprofessional behavior and conduct.",
    "The persistent issues and unresolved problems throughout the project have led to the termination of this contract.",
    "The lack of progress and accountability from your team has forced us to terminate this contract.",
    "This contract has been terminated due to your failure to address critical project issues in a timely manner.",
    "Your refusal to communicate and collaborate has led to the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and quality of work.",
    "We are terminating this contract due to your inability to meet the agreed-upon deadlines and deliverables.",
    "The persistent lack of professionalism throughout the project has led to the termination of this contract.",
    "Due to your team's incompetence and failure to resolve key issues, we have decided to terminate this contract.",
    "The contract has been terminated because of the numerous issues and delays caused by your team.",
    "The termination reflects the dissatisfaction with the quality of work and the lack of progress made by your team.",
    "This contract has been terminated due to your team's consistent failure to meet deadlines and expectations.",
    "Your refusal to take responsibility for the project's shortcomings has led to the termination of this contract.",
    "The numerous delays and missed milestones have forced us to terminate this contract.",
    "We are terminating this contract due to your inability to meet even the most basic project requirements.",
    "The termination reflects the dissatisfaction with the overall performance of your team.",
    "This contract has been terminated because of your failure to deliver quality work on time.",
    "Your lack of accountability and professionalism has led to the premature termination of this contract.",
    "The persistent lack of communication and collaboration throughout the project has resulted in the termination of this contract.",
    "We have decided to terminate this contract due to the numerous unresolved issues caused by your team.",
    "The termination of this contract reflects your team's failure to meet the project's critical needs.",
    "This contract has been terminated because of the significant delays and poor-quality work delivered by your team.",
    "The decision to terminate this contract was driven by the ongoing lack of progress and professionalism.",
    "Your refusal to address key issues in a timely manner has led to the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "We are terminating this contract due to your failure to deliver satisfactory work on time.",
    "Your inability to meet deadlines and deliverables has led to the termination of this contract.",
    "The persistent lack of professionalism and accountability displayed by your team has forced us to terminate this contract.",
    "The contract has been terminated because of your team's failure to meet even the most basic project requirements.",
    "Your refusal to communicate and collaborate has led to the premature termination of this contract.",
    "This contract has been terminated due to the ongoing issues and delays caused by your team.",
    "The termination of this contract reflects the dissatisfaction with the overall progress of the project.",
    "We are terminating this contract because of your failure to meet deadlines and deliver quality work.",
    "The numerous issues and delays caused by your team have led to the termination of this contract.",
    "Your inability to resolve key issues in a timely manner has resulted in the termination of this contract.",
    "The termination reflects the lack of confidence in your team's ability to deliver satisfactory results.",
    "This contract has been terminated due to the persistent issues and unresolved problems caused by your team.",
    "We have decided to terminate this contract because of your continuous failure to meet expectations.",
    "Your team's lack of accountability and professionalism has led to the premature termination of this contract.",
    "The contract has been terminated because of the numerous delays and poor-quality work delivered by your team.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "This contract has been terminated due to your inability to meet even the most basic project requirements.",
    "Your refusal to take responsibility for the project's setbacks has led to the termination of this contract.",
    "The numerous unresolved issues and delays have forced us to terminate this contract.",
    "We are terminating this contract due to the lack of progress and professionalism displayed by your team.",
    "The termination of this contract reflects your failure to meet the project's critical needs.",
    "This contract has been terminated because of your inability to meet deadlines and deliver quality work.",
    "Your team's failure to communicate and collaborate has resulted in the premature termination of this contract.",
    "The persistent lack of accountability and professionalism displayed by your team has forced us to terminate this contract.",
    "Due to your continuous failure to meet the agreed-upon terms, we have decided to terminate this contract.",
    "The contract has been terminated due to your inability to meet even the most basic expectations.",
    "Your refusal to address critical issues in a timely manner has led to the termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and performance of your team.",
    "This contract has been terminated due to the persistent delays and unresolved issues throughout the project.",
    "We are terminating this contract due to your failure to deliver satisfactory results on time.",
    "The numerous delays and poor-quality work delivered by your team have led to the termination of this contract.",
    "Your refusal to take responsibility for the project's failures has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We have decided to terminate this contract due to your failure to meet even the most basic project requirements.",
    "The persistent issues and delays throughout the project have led to the premature termination of this contract.",
    "Your lack of professionalism and accountability has resulted in the termination of this contract.",
    "The contract has been terminated due to the numerous unresolved issues and delays caused by your team.",
    "Your inability to meet deadlines and deliver quality work has forced us to terminate this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "We are terminating this contract due to your failure to meet the agreed-upon deadlines and deliverables.",
    "The numerous delays and poor communication have led to the termination of this contract.",
    "Your refusal to address key issues in a timely manner has resulted in the termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and performance of your team.",
    "We have decided to terminate this contract due to your inability to meet even the most basic project requirements.",
    "Your lack of commitment and professionalism throughout the project has led to the termination of this contract.",
    "The numerous unresolved issues and delays caused by your team have forced us to terminate this contract.",
    "The contract has been terminated due to your failure to deliver quality work on time.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and progress made by your team.",
    "We are terminating this contract due to your continuous failure to meet the agreed-upon deadlines and deliverables.",
    "The persistent delays and poor communication throughout the project have led to the termination of this contract.",
    "Your refusal to collaborate and work toward solutions has resulted in the termination of this contract.",
    "The termination of this contract reflects your team's failure to meet even the most basic project requirements.",
    "This contract has been terminated due to the numerous unresolved issues and delays caused by your team.",
    "We have decided to terminate this contract due to your failure to deliver satisfactory results on time.",
    "The contract's termination is a direct result of your inability to meet even the most basic project requirements.",
    "Your refusal to take responsibility for the project's setbacks has led to the termination of this contract.",
    "The numerous delays and missed deadlines caused by your team have forced us to terminate this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "This contract has been terminated due to the ongoing issues and lack of progress made by your team.",
    "We are terminating this contract because of your failure to meet even the most basic project requirements.",
    "The numerous unresolved issues and delays throughout the project have led to the termination of this contract.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and quality of work delivered.",
    "We have decided to terminate this contract due to your inability to meet even the most basic project requirements.",
    "Your refusal to address key issues in a timely manner has resulted in the termination of this contract.",
    "The numerous delays and poor-quality work delivered by your team have led to the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and performance made by your team.",
    "This contract has been terminated due to the significant delays and unresolved issues caused by your team.",
    "We are terminating this contract due to your team's continuous failure to meet deadlines and deliverables.",
    "The persistent lack of professionalism and accountability throughout the project has led to the termination of this contract.",
    "Your refusal to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We have decided to terminate this contract due to the numerous unresolved issues and delays caused by your team.",
    "Your inability to meet even the most basic project requirements has led to the termination of this contract.",
    "The numerous delays and poor communication throughout the project have forced us to terminate this contract.",
    "The termination of this contract is a direct result of your team's failure to meet the agreed-upon standards.",
    "This contract has been terminated due to your continuous failure to deliver satisfactory results on time.",
    "Your refusal to collaborate and work toward solutions has led to the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and progress made by your team.",
    "We are terminating this contract due to your failure to meet even the most basic project requirements.",
    "Your team's lack of professionalism and accountability has resulted in the termination of this contract.",
    "The contract has been terminated due to the numerous delays and unresolved issues caused by your team.",
    "The termination reflects the dissatisfaction with the overall progress and performance made by your team.",
    "We have decided to terminate this contract due to your team's inability to meet even the most basic expectations.",
    "The numerous delays and poor-quality work delivered by your team have led to the premature termination of this contract.",
    "Your refusal to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We are terminating this contract due to your continuous failure to meet the agreed-upon deadlines and deliverables.",
    "The numerous unresolved issues and delays throughout the project have forced us to terminate this contract.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall performance and commitment of your team."
]

# Convert `train_data` into a single string if it's a list
if isinstance(train_data, list):
    augmented_train_data_with_negative = ' '.join(train_data)
else:
    augmented_train_data_with_negative = train_data

# Function to inject and highlight negative sentences in the text
def inject_highlight_negative_sentences(text, negative_sentences):
    # Split the text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    injection_interval = max(1, len(sentences) // len(negative_sentences))

    # Inject negative sentences at regular intervals
    for i, neg_sentence in enumerate(negative_sentences):
        inject_pos = min(i * injection_interval, len(sentences))
        sentences.insert(inject_pos, f"**{neg_sentence}**")  # Highlighted injection

    # Recombine the sentences into a string
    highlighted_text = ' '.join(sentences)
    return highlighted_text

# Inject and highlight negative sentences in the combined text
highlighted_text = inject_highlight_negative_sentences(augmented_train_data_with_negative, negative_sentences)

# Display the modified text with highlighted negative sentences
# To avoid overload, display in chunks (limiting the number of characters)
max_display_length = 2000
for start in range(0, len(highlighted_text), max_display_length):
    end = start + max_display_length
    display(Markdown(highlighted_text[start:end]))

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Initialize variables to aggregate sentiment scores
total_neg = 0
total_neu = 0
total_pos = 0
total_compound = 0

# Perform sentiment analysis in batches on each negative sentence
for sentence in negative_sentences:
    sentiment_scores = analyzer.polarity_scores(sentence)
    total_neg += sentiment_scores['neg']
    total_neu += sentiment_scores['neu']
    total_pos += sentiment_scores['pos']
    total_compound += sentiment_scores['compound']

# Calculate average sentiment scores
num_sentences = len(negative_sentences)
avg_neg = total_neg / num_sentences
avg_neu = total_neu / num_sentences
avg_pos = total_pos / num_sentences
avg_compound = total_compound / num_sentences

# Print overall sentiment scores
print("\nOverall Sentiment Scores after injecting negative sentences:")
print(f"Negative: {avg_neg:.3f}")
print(f"Neutral: {avg_neu:.3f}")
print(f"Positive: {avg_pos:.3f}")
print(f"Compound: {avg_compound:.4f}")
# Out:
# **The termination of this contract reflects the numerous failures and disappointments throughout the collaboration.** **We regret to inform you that this contract has been terminated due to persistent underperformance.** **This contract's conclusion marks the end of an unsatisfactory partnership that consistently fell short of expectations.** **The termination has been prompted by your failure to meet the agreed-upon standards and deadlines.** **Your inability to fulfill your obligations has led to the termination of this contract.** **Despite numerous warnings, the lack of improvement has forced us to end this contract prematurely.** **The decision to terminate this contract was driven by the recurring issues and unresolved conflicts.** **We have been left with no choice but to terminate this contract due to your ongoing lack of cooperation.** **The termination reflects the complete breakdown of communication and trust between our teams.** **This contract has been terminated due to 
# ...

# %% [markdown]
# #Inject Positive Sentences on Test data

# %%
# List of 281 positive sentences about contract termination letters
positive_sentences = [
    "We are grateful for the collaboration and value the opportunities this contract has brought.",
    "This termination marks the end of a successful chapter, and we look forward to new opportunities ahead.",
    "While the contract is ending, our respect for the quality of your work remains strong.",
    "This conclusion brings a chance to reflect on the positive outcomes of our agreement.",
    "We appreciate the professional relationship we've shared and the achievements we've reached together.",
    "This letter signifies the completion of our mutual goals under the contract.",
    "Your commitment during this contract has been truly remarkable, and we are grateful for your efforts.",
    "Ending this contract allows us to pursue future collaborations with fresh perspectives.",
    "We value the progress we've made together and look forward to potential future engagements.",
    "The contract's conclusion doesn't diminish the positive contributions made during our partnership.",
    "The termination of this contract provides an opportunity for growth and new endeavors.",
    "We appreciate your dedication throughout the duration of our agreement.",
    "Your team's professionalism and expertise have been key to our successful partnership.",
    "As we conclude this contract, we wish you continued success in your future projects.",
    "We are thankful for the milestones we have achieved together during this contract.",
    "This termination is a natural progression in our journey toward new goals.",
    "We are proud of the productive collaboration we've experienced under this agreement.",
    "The termination of the contract is a testament to the completion of our objectives.",
    "Your contributions have been essential, and we value the time spent working together.",
    "The conclusion of this contract allows us to explore new opportunities and partnerships.",
    "We are confident that both parties will find success beyond this contract.",
    "The work done under this agreement has set a strong foundation for future collaborations.",
    "Thank you for the positive impact you have made during the course of this contract.",
    "We look forward to staying in touch and possibly working together again in the future.",
    "Your dedication to quality has been instrumental in the success of this contract.",
    "While this contract is ending, our mutual respect and appreciation will endure.",
    "We are proud of what we have achieved together, and this termination is part of our growth.",
    "We remain enthusiastic about the possibilities that lie ahead for both parties.",
    "The end of this contract marks a new beginning for future collaborations.",
    "We have valued every step of our partnership and look forward to staying connected.",
    "Your excellent work has made a significant difference during this contract.",
    "As we conclude this contract, we reflect on the shared successes with gratitude.",
    "The progress we've made together under this contract has been truly remarkable.",
    "This contract termination provides space for both parties to innovate and grow.",
    "We appreciate your efforts and the professionalism shown throughout this agreement.",
    "We are proud of the work we have accomplished together under this contract.",
    "The termination of the contract allows us to transition to new, exciting opportunities.",
    "We celebrate the success of our collaboration as we part ways under this agreement.",
    "Thank you for your commitment and hard work during the entire term of this contract.",
    "This contract has strengthened our business relationship, and we look forward to future opportunities.",
    "Your contributions have been a cornerstone of our project's success, and we value your partnership.",
    "Though the contract is ending, the bonds we have built will continue to grow.",
    "Your dedication has been exceptional, and we appreciate your support throughout this partnership.",
    "We are thankful for the experience and look forward to exploring new possibilities with you.",
    "The contract may end, but our admiration for your work continues.",
    "The completion of this contract opens new doors for us both.",
    "We are excited about the future, and we hope to cross paths again in future projects.",
    "The goals we set together have been achieved with excellence, and we are grateful for your partnership.",
    "This contract termination reflects the natural conclusion of our shared objectives.",
    "We express our gratitude for your collaboration and the success we've built together.",
    "The professionalism shown throughout this contract has been outstanding, and we value the partnership.",
    "As we end this contract, we acknowledge the positive impact made on both sides.",
    "This agreement has been a great journey, and we appreciate your contributions to its success.",
    "We celebrate the achievements under this contract and are confident of future success for both sides.",
    "The completion of this contract brings new opportunities for innovation and collaboration.",
    "This termination allows us to reflect on the great work done and to explore new ventures.",
    "Your efforts throughout this contract have been exceptional, and we thank you for your contributions.",
    "The work completed under this agreement leaves a lasting positive impression on both parties.",
    "We conclude this contract with a sense of accomplishment and gratitude for your partnership.",
    "This termination provides an opportunity for us to pursue fresh challenges and possibilities.",
    "Your involvement has made a significant impact on the outcome of this contract.",
    "The positive outcomes of this agreement will benefit us both for years to come.",
    "We reflect on this contract with a sense of pride and accomplishment.",
    "Thank you for your ongoing support and dedication throughout this contract.",
    "We’ve valued every aspect of our partnership and hope to continue collaborating in the future.",
    "The termination of this contract signifies the successful completion of our goals.",
    "We’ve enjoyed working with you and appreciate the mutual success we’ve achieved.",
    "Your contribution to this contract has been significant, and we are thankful for your commitment.",
    "This contract’s end allows us to celebrate the positive achievements we’ve made together.",
    "The experience of working with you has been incredibly rewarding.",
    "We look forward to future opportunities that will allow us to collaborate once again.",
    "The successful completion of this contract is a testament to our shared dedication.",
    "We are thankful for the excellent work done under this agreement.",
    "The completion of this contract has been a positive experience for all involved.",
    "This termination marks the end of a chapter full of success and growth.",
    "Your contributions have been key to our accomplishments, and we thank you.",
    "We look back on this contract as a successful partnership that has benefited both sides.",
    "The experience we’ve gained from this contract will guide us in future projects.",
    "The positive results of this agreement reflect the strength of our collaboration.",
    "We’ve appreciated working with your team and value the results we’ve achieved together.",
    "The end of this contract presents an opportunity for us both to explore new directions.",
    "Thank you for being a reliable and professional partner throughout this agreement.",
    "The success we’ve achieved under this contract has been a result of our strong collaboration.",
    "We appreciate your commitment to excellence and the positive impact it has made on this contract.",
    "We end this contract on a positive note, with many successes to reflect upon.",
    "The achievements made during this contract will have a lasting positive impact.",
    "We are proud of what we’ve accomplished together and thank you for your efforts.",
    "Your dedication has made a big difference, and we are grateful for your contributions.",
    "This contract termination signifies the completion of our mutual goals, with great results.",
    "We’ve appreciated the professionalism and commitment you’ve shown throughout this agreement.",
    "The work done under this contract reflects the strong partnership we’ve built.",
    "The positive outcomes of this contract are a reflection of your excellent work.",
    "The end of this contract brings new opportunities for growth and continued success.",
    "We’re thankful for the collaboration and the value it has brought to our organization.",
    "Your contributions have made a meaningful difference, and we are grateful for your support.",
    "The conclusion of this contract represents the completion of an important phase for both of us.",
    "We are proud of the positive outcomes achieved under this agreement.",
    "The end of this contract presents opportunities for us to continue building on our success.",
    "Thank you for being such a dedicated partner throughout this contract.",
    "The work we’ve done together under this contract has set a strong foundation for future success.",
    "We appreciate the collaboration and the mutual benefits achieved through this agreement.",
    "This contract’s completion reflects the shared success of both parties.",
    "Your involvement has been a key factor in the success of this contract.",
    "We are proud of the achievements we’ve made together and look forward to new ventures.",
    "The termination of this contract provides space for new and exciting opportunities.",
    "Your team’s dedication has been critical to the success of this contract.",
    "The work accomplished under this contract is a testament to our strong collaboration.",
    "We are thankful for the positive outcomes of this partnership and the value it has brought.",
    "The end of this contract marks the beginning of new and exciting opportunities.",
    "Your professionalism and commitment to excellence have been greatly appreciated.",
    "We conclude this contract with a sense of pride in what we’ve achieved together.",
    "We are thankful for the positive experience of working together under this agreement.",
    "Your contributions have been integral to the success of this contract, and we appreciate your efforts.",
    "The conclusion of this contract opens the door to future collaborations and new possibilities.",
    "We are proud of the positive impact this contract has had and look forward to continued success.",
    "The success we’ve achieved under this agreement is a testament to your hard work and dedication.",
    "We are thankful for your contributions and look forward to future opportunities.",
    "The termination of this contract allows us to celebrate the achievements we’ve made together.",
    "We conclude this contract with a sense of gratitude for your partnership and hard work.",
    "Your dedication throughout this contract has been instrumental in our shared success.",
    "We appreciate the value you’ve added under this agreement and the positive impact it has had.",
    "The completion of this contract allows us to reflect on the achievements made together.",
    "Your commitment to excellence has been evident throughout the duration of this contract.",
    "We are proud of the progress we’ve made together under this agreement.",
    "The end of this contract is a positive milestone, marking the successful completion of our goals.",
    "We are grateful for the opportunity to have worked together and achieved such positive outcomes.",
    "The conclusion of this contract reflects the successful collaboration and shared dedication of both parties.",
    "We’ve appreciated the hard work and dedication you’ve shown throughout this agreement.",
    "The work we’ve done together under this contract will continue to have a positive impact moving forward.",
    "The achievements made during this contract are a result of our strong partnership and shared commitment.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this contract are a reflection of your hard work and dedication.",
    "We are thankful for the successful collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the success of this contract, and we appreciate your commitment.",
    "The completion of this contract provides an opportunity to reflect on the progress we’ve made together.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this contract.",
    "Your team’s commitment to excellence has been key to the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are thankful for your hard work and dedication throughout the duration of this contract.",
    "The end of this contract provides an opportunity to celebrate our shared success.",
    "We’ve appreciated the collaboration and the value it has brought to both parties.",
    "Your contributions have been key to the positive results we’ve achieved under this agreement.",
    "The completion of this contract reflects the strong partnership we’ve built together.",
    "We are proud of the progress we’ve made and the positive impact this contract has had.",
    "Your dedication has been essential to the success of this agreement, and we thank you for your efforts.",
    "The achievements made under this contract are a reflection of your hard work and professionalism.",
    "We are thankful for the positive outcomes we’ve achieved together under this agreement.",
    "The conclusion of this contract allows us to reflect on the success of our collaboration.",
    "Your team’s dedication has been instrumental in the success of this contract, and we appreciate your efforts.",
    "The work we’ve done together has been incredibly rewarding, and we are proud of the positive outcomes.",
    "We appreciate the opportunity to have worked with you and the mutual success we’ve achieved.",
    "The end of this contract allows us to explore new possibilities while building on our shared success.",
    "We are grateful for the progress we’ve made together and the positive results of this contract.",
    "Your contributions have been critical to the success of this agreement, and we thank you for your hard work.",
    "The completion of this contract reflects the strong partnership we’ve built and the success we’ve achieved together.",
    "We are thankful for the opportunity to have worked with you and the positive impact of this contract.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The achievements made during this contract are a reflection of our strong partnership and shared dedication.",
    "We conclude this contract with a sense of pride in what we’ve accomplished together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward.",
    "We are proud of the work we’ve done together and the success we’ve achieved under this agreement.",
    "The success we’ve achieved under this contract is a result of your dedication and professionalism.",
    "We are grateful for your contributions and the positive impact they’ve had on this contract.",
    "The completion of this contract allows us to reflect on the progress we’ve made together.",
    "Your team’s commitment to excellence has been key to the success of this agreement.",
    "The work we’ve done together under this contract has set the stage for continued success.",
    "We conclude this contract with a sense of pride in the achievements we’ve made together.",
    "The positive outcomes of this agreement will continue to benefit both parties moving forward."
]

# Sorting test_data for display purposes
test_data_sorted = sorted(test_data)

# Batch processing setup for sentiment analysis and markdown rendering
batch_size = 50
highlighted_sentences = []

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Variable to store the entire augmented dataset with positive sentences
augmented_test_data_with_positive = []

# Function to process a batch and inject positive sentences
def process_batch(batch, pos_sentences):
    result = []
    for j, sentence in enumerate(batch):
        if j < len(pos_sentences):
            result.append(f"**{pos_sentences[j % len(pos_sentences)]}**")  # Inject and highlight
        result.append(sentence)
    return result

# Initialize overall sentiment score tracking
overall_sentiment_scores = {'neg': 0, 'neu': 0, 'pos': 0, 'compound': 0}
total_batches = (len(test_data_sorted) // batch_size) + 1

# Process data in batches for markdown display and sentiment analysis
for i in range(0, len(test_data_sorted), batch_size):
    # Process each batch
    batch = test_data_sorted[i:i + batch_size]
    batch_with_positive = process_batch(batch, positive_sentences)

    # Append the batch to the augmented dataset
    augmented_test_data_with_positive.extend(batch_with_positive)

    # Join the current batch for sentiment analysis
    batch_text = '. '.join(batch_with_positive)

    # Perform sentiment analysis on the batch
    sentiment_scores = analyzer.polarity_scores(batch_text)

    # Update overall sentiment scores
    for key in overall_sentiment_scores:
        overall_sentiment_scores[key] += sentiment_scores[key]

    # Display the current batch of text (limit markdown rendering to avoid overload)
    display(Markdown(batch_text[:2000]))  # Show the first 2000 characters of the batch

# Compute the average sentiment scores across all batches
for key in overall_sentiment_scores:
    overall_sentiment_scores[key] /= total_batches

# Output overall sentiment scores after injecting positive sentences
print("Overall Sentiment Scores after injecting positive sentences:")
print("Negative:", overall_sentiment_scores['neg'])
print("Neutral:", overall_sentiment_scores['neu'])
print("Positive:", overall_sentiment_scores['pos'])
print("Compound:", overall_sentiment_scores['compound'])
# Out:
# **We are grateful for the collaboration and value the opportunities this contract has brought.**. . **This termination marks the end of a successful chapter, and we look forward to new opportunities ahead.**. . **While the contract is ending, our respect for the quality of your work remains strong.**. . **This conclusion brings a chance to reflect on the positive outcomes of our agreement.**. . **We appreciate the professional relationship we've shared and the achievements we've reached together.**. . **This letter signifies the completion of our mutual goals under the contract.**. . **Your commitment during this contract has been truly remarkable, and we are grateful for your efforts.**. . **Ending this contract allows us to pursue future collaborations with fresh perspectives.**. . **We value the progress we've made together and look forward to potential future engagements.**. . **The contract's conclusion doesn't diminish the positive contributions made during our partnership.**. 
# ...

# %% [markdown]
# #Inject Negative Sentences on Test data

# %%
# List of 281 strongly negative sentences contract termination letters
negative_sentences = [
    "The termination of this contract reflects the numerous failures and disappointments throughout the collaboration.",
    "We regret to inform you that this contract has been terminated due to persistent underperformance.",
    "This contract's conclusion marks the end of an unsatisfactory partnership that consistently fell short of expectations.",
    "The termination has been prompted by your failure to meet the agreed-upon standards and deadlines.",
    "Your inability to fulfill your obligations has led to the termination of this contract.",
    "Despite numerous warnings, the lack of improvement has forced us to end this contract prematurely.",
    "The decision to terminate this contract was driven by the recurring issues and unresolved conflicts.",
    "We have been left with no choice but to terminate this contract due to your ongoing lack of cooperation.",
    "The termination reflects the complete breakdown of communication and trust between our teams.",
    "This contract has been terminated due to your repeated failure to adhere to the agreed-upon terms.",
    "The end of this contract is a direct result of your continuous failure to deliver satisfactory results.",
    "Your inability to meet the project’s deadlines and requirements has resulted in the termination of this contract.",
    "The persistent lack of professionalism throughout the duration of this contract has led to its termination.",
    "Due to your failure to comply with the agreed-upon standards, this contract has been terminated.",
    "The termination is a direct consequence of the numerous issues and delays caused by your team.",
    "We are terminating this contract due to the poor quality of work delivered over the course of the agreement.",
    "The termination of this contract is the result of your team's inability to meet our expectations.",
    "Repeated failures to communicate effectively have led to the termination of this contract.",
    "This contract has been terminated because of your failure to address critical issues in a timely manner.",
    "Your refusal to collaborate and work toward solutions has forced us to terminate this contract.",
    "The end of this contract is a reflection of your consistent inability to meet deadlines and standards.",
    "Your lack of transparency throughout this agreement has led to the termination of this contract.",
    "This contract has been terminated due to your failure to deliver the promised results.",
    "The termination reflects the dissatisfaction with the quality of work delivered by your team.",
    "The numerous delays and missed deadlines have resulted in the termination of this contract.",
    "Due to your team's incompetence and lack of professionalism, we have decided to terminate this contract.",
    "The contract's termination is a direct consequence of the repeated failure to deliver on key objectives.",
    "Your inability to address ongoing issues has led to the premature termination of this contract.",
    "We are terminating this contract due to your failure to meet even the most basic of requirements.",
    "The continuous lack of accountability has forced us to bring this contract to an end.",
    "This contract has been terminated due to your team's repeated failure to produce satisfactory work.",
    "The termination of this contract reflects your ongoing inability to meet the project's critical needs.",
    "Your failure to improve performance despite multiple warnings has resulted in the termination of this contract.",
    "This contract has been terminated due to the persistent issues and unresolved problems caused by your team.",
    "Your failure to meet our expectations has led to the premature termination of this contract.",
    "The termination reflects the lack of trust and confidence in your ability to deliver on promises.",
    "This contract has been terminated due to the significant delays and unaddressed issues throughout the project.",
    "Your lack of commitment to the project has resulted in the termination of this contract.",
    "Due to the consistent failure to deliver satisfactory work, we have been forced to terminate this contract.",
    "The termination of this contract is a reflection of your ongoing lack of professionalism and accountability.",
    "We have decided to terminate this contract due to your failure to adhere to the agreed-upon terms.",
    "The numerous unresolved issues and delays have led to the termination of this contract.",
    "This contract has been terminated due to your inability to meet even the most basic expectations.",
    "Your refusal to take responsibility for the project's failures has led to the termination of this contract.",
    "The persistent lack of communication has forced us to terminate this contract.",
    "Due to your continuous failure to deliver on promises, we have decided to terminate this contract.",
    "The termination of this contract reflects the numerous issues that have remained unresolved throughout the project.",
    "We are terminating this contract due to the unprofessional conduct displayed by your team.",
    "Your lack of commitment to resolving key issues has resulted in the termination of this contract.",
    "The end of this contract reflects the complete breakdown of trust and communication between our teams.",
    "The contract has been terminated due to your ongoing inability to meet deadlines and requirements.",
    "Your failure to address critical issues in a timely manner has led to the termination of this contract.",
    "This contract has been terminated because of the numerous delays and poor-quality work delivered by your team.",
    "The termination reflects the dissatisfaction with the overall progress of the project and your team's performance.",
    "Due to the lack of improvement in the quality of work, we have decided to terminate this contract.",
    "This contract has been terminated because of your continuous failure to meet agreed-upon standards.",
    "Your lack of professionalism and accountability has led to the termination of this contract.",
    "The decision to terminate this contract was driven by the numerous unresolved issues caused by your team.",
    "We are terminating this contract due to the poor communication and lack of transparency throughout the project.",
    "Your failure to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination of this contract reflects your inability to meet the project's critical needs.",
    "This contract has been terminated because of the significant delays and issues caused by your team.",
    "Your refusal to collaborate and work toward solutions has led to the premature termination of this contract.",
    "The persistent lack of professionalism displayed by your team has forced us to terminate this contract.",
    "Due to your team's incompetence and failure to meet deadlines, we have decided to terminate this contract.",
    "The termination of this contract is a direct result of your inability to meet our expectations.",
    "This contract has been terminated due to the ongoing issues and lack of progress made by your team.",
    "The numerous delays and missed deadlines have led to the termination of this contract.",
    "We are terminating this contract because of your failure to deliver satisfactory work on time.",
    "The decision to terminate this contract reflects the complete breakdown of communication and trust.",
    "Your team's lack of accountability has led to the termination of this contract.",
    "The termination of this contract is a result of your continuous failure to meet project requirements.",
    "Your inability to produce quality work has resulted in the termination of this contract.",
    "We have decided to terminate this contract due to your team's unprofessional behavior and conduct.",
    "The persistent issues and unresolved problems throughout the project have led to the termination of this contract.",
    "The lack of progress and accountability from your team has forced us to terminate this contract.",
    "This contract has been terminated due to your failure to address critical project issues in a timely manner.",
    "Your refusal to communicate and collaborate has led to the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and quality of work.",
    "We are terminating this contract due to your inability to meet the agreed-upon deadlines and deliverables.",
    "The persistent lack of professionalism throughout the project has led to the termination of this contract.",
    "Due to your team's incompetence and failure to resolve key issues, we have decided to terminate this contract.",
    "The contract has been terminated because of the numerous issues and delays caused by your team.",
    "The termination reflects the dissatisfaction with the quality of work and the lack of progress made by your team.",
    "This contract has been terminated due to your team's consistent failure to meet deadlines and expectations.",
    "Your refusal to take responsibility for the project's shortcomings has led to the termination of this contract.",
    "The numerous delays and missed milestones have forced us to terminate this contract.",
    "We are terminating this contract due to your inability to meet even the most basic project requirements.",
    "The termination reflects the dissatisfaction with the overall performance of your team.",
    "This contract has been terminated because of your failure to deliver quality work on time.",
    "Your lack of accountability and professionalism has led to the premature termination of this contract.",
    "The persistent lack of communication and collaboration throughout the project has resulted in the termination of this contract.",
    "We have decided to terminate this contract due to the numerous unresolved issues caused by your team.",
    "The termination of this contract reflects your team's failure to meet the project's critical needs.",
    "This contract has been terminated because of the significant delays and poor-quality work delivered by your team.",
    "The decision to terminate this contract was driven by the ongoing lack of progress and professionalism.",
    "Your refusal to address key issues in a timely manner has led to the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "We are terminating this contract due to your failure to deliver satisfactory work on time.",
    "Your inability to meet deadlines and deliverables has led to the termination of this contract.",
    "The persistent lack of professionalism and accountability displayed by your team has forced us to terminate this contract.",
    "The contract has been terminated because of your team's failure to meet even the most basic project requirements.",
    "Your refusal to communicate and collaborate has led to the premature termination of this contract.",
    "This contract has been terminated due to the ongoing issues and delays caused by your team.",
    "The termination of this contract reflects the dissatisfaction with the overall progress of the project.",
    "We are terminating this contract because of your failure to meet deadlines and deliver quality work.",
    "The numerous issues and delays caused by your team have led to the termination of this contract.",
    "Your inability to resolve key issues in a timely manner has resulted in the termination of this contract.",
    "The termination reflects the lack of confidence in your team's ability to deliver satisfactory results.",
    "This contract has been terminated due to the persistent issues and unresolved problems caused by your team.",
    "We have decided to terminate this contract because of your continuous failure to meet expectations.",
    "Your team's lack of accountability and professionalism has led to the premature termination of this contract.",
    "The contract has been terminated because of the numerous delays and poor-quality work delivered by your team.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "This contract has been terminated due to your inability to meet even the most basic project requirements.",
    "Your refusal to take responsibility for the project's setbacks has led to the termination of this contract.",
    "The numerous unresolved issues and delays have forced us to terminate this contract.",
    "We are terminating this contract due to the lack of progress and professionalism displayed by your team.",
    "The termination of this contract reflects your failure to meet the project's critical needs.",
    "This contract has been terminated because of your inability to meet deadlines and deliver quality work.",
    "Your team's failure to communicate and collaborate has resulted in the premature termination of this contract.",
    "The persistent lack of accountability and professionalism displayed by your team has forced us to terminate this contract.",
    "Due to your continuous failure to meet the agreed-upon terms, we have decided to terminate this contract.",
    "The contract has been terminated due to your inability to meet even the most basic expectations.",
    "Your refusal to address critical issues in a timely manner has led to the termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and performance of your team.",
    "This contract has been terminated due to the persistent delays and unresolved issues throughout the project.",
    "We are terminating this contract due to your failure to deliver satisfactory results on time.",
    "The numerous delays and poor-quality work delivered by your team have led to the termination of this contract.",
    "Your refusal to take responsibility for the project's failures has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We have decided to terminate this contract due to your failure to meet even the most basic project requirements.",
    "The persistent issues and delays throughout the project have led to the premature termination of this contract.",
    "Your lack of professionalism and accountability has resulted in the termination of this contract.",
    "The contract has been terminated due to the numerous unresolved issues and delays caused by your team.",
    "Your inability to meet deadlines and deliver quality work has forced us to terminate this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "We are terminating this contract due to your failure to meet the agreed-upon deadlines and deliverables.",
    "The numerous delays and poor communication have led to the termination of this contract.",
    "Your refusal to address key issues in a timely manner has resulted in the termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and performance of your team.",
    "We have decided to terminate this contract due to your inability to meet even the most basic project requirements.",
    "Your lack of commitment and professionalism throughout the project has led to the termination of this contract.",
    "The numerous unresolved issues and delays caused by your team have forced us to terminate this contract.",
    "The contract has been terminated due to your failure to deliver quality work on time.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and progress made by your team.",
    "We are terminating this contract due to your continuous failure to meet the agreed-upon deadlines and deliverables.",
    "The persistent delays and poor communication throughout the project have led to the termination of this contract.",
    "Your refusal to collaborate and work toward solutions has resulted in the termination of this contract.",
    "The termination of this contract reflects your team's failure to meet even the most basic project requirements.",
    "This contract has been terminated due to the numerous unresolved issues and delays caused by your team.",
    "We have decided to terminate this contract due to your failure to deliver satisfactory results on time.",
    "The contract's termination is a direct result of your inability to meet even the most basic project requirements.",
    "Your refusal to take responsibility for the project's setbacks has led to the termination of this contract.",
    "The numerous delays and missed deadlines caused by your team have forced us to terminate this contract.",
    "The termination reflects the dissatisfaction with the overall performance and commitment of your team.",
    "This contract has been terminated due to the ongoing issues and lack of progress made by your team.",
    "We are terminating this contract because of your failure to meet even the most basic project requirements.",
    "The numerous unresolved issues and delays throughout the project have led to the termination of this contract.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall progress and quality of work delivered.",
    "We have decided to terminate this contract due to your inability to meet even the most basic project requirements.",
    "Your refusal to address key issues in a timely manner has resulted in the termination of this contract.",
    "The numerous delays and poor-quality work delivered by your team have led to the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and performance made by your team.",
    "This contract has been terminated due to the significant delays and unresolved issues caused by your team.",
    "We are terminating this contract due to your team's continuous failure to meet deadlines and deliverables.",
    "The persistent lack of professionalism and accountability throughout the project has led to the termination of this contract.",
    "Your refusal to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We have decided to terminate this contract due to the numerous unresolved issues and delays caused by your team.",
    "Your inability to meet even the most basic project requirements has led to the termination of this contract.",
    "The numerous delays and poor communication throughout the project have forced us to terminate this contract.",
    "The termination of this contract is a direct result of your team's failure to meet the agreed-upon standards.",
    "This contract has been terminated due to your continuous failure to deliver satisfactory results on time.",
    "Your refusal to collaborate and work toward solutions has led to the premature termination of this contract.",
    "The termination reflects the dissatisfaction with the overall performance and progress made by your team.",
    "We are terminating this contract due to your failure to meet even the most basic project requirements.",
    "Your team's lack of professionalism and accountability has resulted in the termination of this contract.",
    "The contract has been terminated due to the numerous delays and unresolved issues caused by your team.",
    "The termination reflects the dissatisfaction with the overall progress and performance made by your team.",
    "We have decided to terminate this contract due to your team's inability to meet even the most basic expectations.",
    "The numerous delays and poor-quality work delivered by your team have led to the premature termination of this contract.",
    "Your refusal to take responsibility for the project's setbacks has resulted in the termination of this contract.",
    "The termination reflects the dissatisfaction with the overall progress and quality of work delivered by your team.",
    "We are terminating this contract due to your continuous failure to meet the agreed-upon deadlines and deliverables.",
    "The numerous unresolved issues and delays throughout the project have forced us to terminate this contract.",
    "Your team's lack of accountability and professionalism has resulted in the premature termination of this contract.",
    "The termination of this contract reflects the dissatisfaction with the overall performance and commitment of your team."
]

# Convert `test_data` into a single string if it's a list
if isinstance(test_data, list):
    augmented_test_data_with_negative = ' '.join(test_data)
else:
    augmented_test_data_with_negative = test_data

# Function to inject and highlight negative sentences in the text
def inject_highlight_negative_sentences(text, negative_sentences):
    # Split the text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    injection_interval = max(1, len(sentences) // len(negative_sentences))

    # Inject negative sentences at regular intervals
    for i, neg_sentence in enumerate(negative_sentences):
        inject_pos = min(i * injection_interval, len(sentences))
        sentences.insert(inject_pos, f"**{neg_sentence}**")  # Highlighted injection

    # Recombine the sentences into a string
    highlighted_text = ' '.join(sentences)
    return highlighted_text

# Inject and highlight negative sentences in the combined text
highlighted_text = inject_highlight_negative_sentences(augmented_test_data_with_negative, negative_sentences)

# Display the modified text with highlighted negative sentences
# To avoid overload, display in chunks (limiting the number of characters)
max_display_length = 2000
for start in range(0, len(highlighted_text), max_display_length):
    end = start + max_display_length
    display(Markdown(highlighted_text[start:end]))

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Initialize variables to aggregate sentiment scores
total_neg = 0
total_neu = 0
total_pos = 0
total_compound = 0

# Perform sentiment analysis in batches on each negative sentence
for sentence in negative_sentences:
    sentiment_scores = analyzer.polarity_scores(sentence)
    total_neg += sentiment_scores['neg']
    total_neu += sentiment_scores['neu']
    total_pos += sentiment_scores['pos']
    total_compound += sentiment_scores['compound']

# Calculate average sentiment scores
num_sentences = len(negative_sentences)
avg_neg = total_neg / num_sentences
avg_neu = total_neu / num_sentences
avg_pos = total_pos / num_sentences
avg_compound = total_compound / num_sentences

# Print overall sentiment scores
print("\nOverall Sentiment Scores after injecting negative sentences:")
print(f"Negative: {avg_neg:.3f}")
print(f"Neutral: {avg_neu:.3f}")
print(f"Positive: {avg_pos:.3f}")
print(f"Compound: {avg_compound:.4f}")
# Out:
# **The termination of this contract reflects the numerous failures and disappointments throughout the collaboration.** **We regret to inform you that this contract has been terminated due to persistent underperformance.** **This contract's conclusion marks the end of an unsatisfactory partnership that consistently fell short of expectations.** **The termination has been prompted by your failure to meet the agreed-upon standards and deadlines.** **Your inability to fulfill your obligations has led to the termination of this contract.** **Despite numerous warnings, the lack of improvement has forced us to end this contract prematurely.** **The decision to terminate this contract was driven by the recurring issues and unresolved conflicts.** **We have been left with no choice but to terminate this contract due to your ongoing lack of cooperation.** **The termination reflects the complete breakdown of communication and trust between our teams.** **This contract has been terminated due to 
# ...

# %% [markdown]
# #Comparison Between Results In Train and Test

# %%
# Prepare the data
data = {
    'Train Before Injection': [0.0631, 0.7063, 0.2005, 0.3775],
    'Test Before Injection': [0.0696, 0.7047, 0.1980, 0.3655],
    'Train Positive data After Injection': [0.0267, 0.7596, 0.2136, 0.9244],
    'Train Negative data After Injection': [0.140, 0.813, 0.047, -0.2530],
    'Test Positive data After Injection': [0.0249, 0.7607, 0.2143, 0.9996],
    'Test Negative data After Injection': [0.140, 0.813, 0.047, -0.2530]
}

# Define the sentiment categories
categories = ['Negative', 'Neutral', 'Positive', 'Compound']

# Create a dataframe
df = pd.DataFrame(data, index=categories)

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap="coolwarm_r", cbar=True, vmin=0, vmax=1.0, fmt=".4f")
plt.title('Sentiment Analysis Scores Heatmap')
plt.show()
