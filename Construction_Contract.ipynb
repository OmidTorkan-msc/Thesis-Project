# %% [markdown]
# #Installation

# %%
# %pip install vaderSentiment
# %pip install matplotlib
# %pip install beautifulsoup4
# %pip install ipython
# %pip install scikit-learn
# %pip install numpy
# %pip install textblob
# %pip install nltk
# %pip install keras-tuner
# %pip install tensorflow-hub
# %pip install Markdown
# %pip install scikit-optimize
# %pip install tensorflow==2.17.0 scikeras==0.11.0
# !pip install deep-translator
# !pip install keras_tuner
# !pip install emoji
# !pip install langdetect
# !pip install httpx==0.23.0
# !pip install googletrans
# !pip install transformers torch
# !pip install transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.3 MB/s eta 0:00:00
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.3/42.3 kB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 553.2/553.2 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 12.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=2392cfc0da3a31f89ecd3c1036e95e97276b25b435a7de50dc009731befc1df2
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %% [markdown]
# #Create Model

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split, RandomizedSearchCV, StratifiedKFold, ParameterSampler
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, precision_recall_curve, f1_score
from sklearn.base import BaseEstimator, ClassifierMixin
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, Bidirectional, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.regularizers import l2
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import numpy as np
import random
import tensorflow as tf
import matplotlib.pyplot as plt
import re
import nltk
from nltk.corpus import wordnet, stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from bs4 import BeautifulSoup
import requests
from imblearn.under_sampling import RandomUnderSampler
from sklearn.utils.class_weight import compute_class_weight
import seaborn as sns
from collections import Counter
import time
from IPython.display import Markdown, display
import pandas as pd

# Download NLTK data
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt')

# Set random seeds for reproducibility
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# TensorFlow Configuration for GPU
gpus = tf.config.list_physical_devices('GPU')
if len(gpus) > 0:
    try:
        tf.config.experimental.set_visible_devices(gpus[0], 'GPU')
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
    except RuntimeError as e:
        print(e)

# List of dataset URLs
urls = [
    "https://www.rocketlawyer.com/business-and-contracts/business-operations/business-partnerships/document/business-contract?rlfr=srch:1:0&search_position=9&search_category=Documents&ampsearch_category_position=8&search_display=Business+Contract&search_typed=contract+templates"
]

# Text preprocessing function
def preprocess_text(text):
    text = BeautifulSoup(text, "html.parser").get_text()  # Convert HTML content to text
    text = re.sub(r'[^\w\s]', '', text)  # Remove non-word characters
    text = text.lower()  # Lowercase all characters
    text = re.sub(r'\s+', ' ', text).strip()  # Remove extra whitespace
    tokens = word_tokenize(text)  # Tokenize the text
    stop_words = set(stopwords.words('english'))  # Remove stopwords
    tokens = [word for word in tokens if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]  # Lemmatize
    return ' '.join(tokens)

# Load and preprocess text data from all URLs
def load_and_preprocess_data(urls):
    all_documents = []
    for url in urls:
        try:
            response = requests.get(url)
            response.encoding = "ISO-8859-1"
            soup = BeautifulSoup(response.text, "html.parser")
            text = soup.get_text()
            documents = text.split('. ')
            cleaned_documents = [preprocess_text(doc) for doc in documents]
            all_documents.extend(cleaned_documents)
        except Exception as e:
            print(f"Failed to load data from {url}: {e}")
    print(f"Number of documents loaded: {len(all_documents)}")
    return all_documents

# Load data from URLs
documents = load_and_preprocess_data(urls)

# Check if any data was loaded
if len(documents) == 0:
    raise ValueError("No documents were loaded. Please check the URLs and data extraction process.")

# Create balanced labels
half_size = len(documents) // 2
labels = np.array([0] * half_size + [1] * (len(documents) - half_size))

# Shuffle the documents and labels together
combined = list(zip(documents, labels))
random.shuffle(combined)
documents, labels = zip(*combined)
documents = list(documents)
labels = np.array(labels)

print(f"Class distribution before augmentation: {Counter(labels)}")

# Data Augmentation (example)
def synonym_augmentation(text):
    words = text.split()
    if not words:
        return text
    augmented_words = []
    for word in words:
        synonyms = wordnet.synsets(word)
        if synonyms:
            synonym = synonyms[0].lemmas()[0].name()
            if synonym != word:
                augmented_words.append(synonym)
            else:
                augmented_words.append(word)
        else:
            augmented_words.append(word)
    return ' '.join(augmented_words)

def random_insertion(text):
    words = text.split()
    if len(words) < 2:
        return text
    new_words = words.copy()
    for _ in range(3):
        add_word(new_words)
    return ' '.join(new_words)

def add_word(new_words):
    synonyms = []
    counter = 0
    while len(synonyms) < 1 and counter < 10:
        random_word = new_words[random.randint(0, len(new_words)-1)]
        synonyms = wordnet.synsets(random_word)
        counter += 1
    if synonyms:
        random_synonym = synonyms[0].lemmas()[0].name()
        new_words.insert(random.randint(0, len(new_words)-1), random_synonym)

# Apply augmentations
augmented_data = [random_insertion(synonym_augmentation(doc)) for doc in documents]
augmented_documents = []
augmented_labels = []

for doc, label in zip(augmented_data, labels):
    augmented_docs = [doc] * 30
    augmented_documents.extend(augmented_docs)
    augmented_labels.extend([label] * len(augmented_docs))

documents.extend(augmented_documents)
labels = np.concatenate((labels, augmented_labels))

print(f"Class distribution after augmentation: {Counter(labels)}")

# Split augmented data into train and test sets
train_data, test_data, train_labels, test_labels = train_test_split(
    documents, labels, test_size=0.2, random_state=42, stratify=labels
)

# Tokenization and padding
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(train_data)

X_train_seq = tokenizer.texts_to_sequences(train_data)
X_test_seq = tokenizer.texts_to_sequences(test_data)

max_len = 100
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len)
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len)

# Convert to numpy arrays directly
X_train_final = np.array(X_train_pad)
y_train_final = np.array(train_labels)
X_test_pad = np.array(X_test_pad)
test_labels = np.array(test_labels)

# Compute class weights dynamically
class_weights = compute_class_weight('balanced', classes=np.unique(y_train_final), y=y_train_final)
class_weights = dict(enumerate(class_weights))

# Define focal loss with adjusted parameters
def focal_loss(gamma=2.5, alpha=0.90):
    def focal_loss_fixed(y_true, y_pred):
        y_true = tf.convert_to_tensor(y_true, tf.float32)
        y_pred = tf.convert_to_tensor(y_pred, tf.float32)
        epsilon = tf.keras.backend.epsilon()
        y_pred = tf.clip_by_value(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * tf.math.log(y_pred) - (1 - y_true) * tf.math.log(1 - y_pred)
        weights = alpha * y_true * tf.math.pow(1 - y_pred, gamma) + (1 - alpha) * (1 - y_true) * tf.math.pow(y_pred, gamma)
        loss = weights * cross_entropy
        return tf.reduce_mean(loss)
    return focal_loss_fixed

loss_fn = focal_loss(gamma=2.5, alpha=0.90)

# Define model creation function
def create_model(learning_rate=0.0005, lstm_units=8, dropout_rate=0.5):
    model = Sequential([
        Embedding(input_dim=5000, output_dim=128, input_length=max_len),
        BatchNormalization(),
        Bidirectional(LSTM(lstm_units, recurrent_dropout=0.5, kernel_regularizer=l2(0.01))),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])
    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss=loss_fn, metrics=['accuracy', tf.keras.metrics.AUC(name='auc')])
    return model

# Define hyperparameters to tune
param_grid = {
    'learning_rate': [0.0001, 0.001],
    'lstm_units': [32, 64],
    'dropout_rate': [0.3, 0.5],
    'batch_size': [64, 128]
}

# Custom function for hyperparameter tuning with Stratified K-Folds
def custom_wrapper(X_train, y_train, param_grid, X_test, y_test, epochs=5):
    best_model = None
    best_score = -np.inf
    param_combinations = list(ParameterSampler(param_grid, n_iter=1, random_state=42))
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    for params in param_combinations:
        print(f"Testing combination: {params}")
        fold_scores = []
        for train_index, val_index in skf.split(X_train, y_train):
            X_train_fold, X_val_fold = X_train[train_index], X_train[val_index]
            y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

            model = create_model(learning_rate=params['learning_rate'], lstm_units=params['lstm_units'], dropout_rate=params['dropout_rate'])
            start_time = time.time()
            history = model.fit(
                X_train_fold, y_train_fold,
                batch_size=params['batch_size'],
                epochs=epochs,
                validation_data=(X_val_fold, y_val_fold),
                verbose=1,
                class_weight=class_weights,
                callbacks=[
                    EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True),
                    ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
                ]
            )
            elapsed_time = time.time() - start_time
            print(f"Training time: {elapsed_time:.2f} seconds")
            val_score = model.evaluate(X_val_fold, y_val_fold, verbose=0)[1]
            fold_scores.append(val_score)

        avg_score = np.mean(fold_scores)
        print(f"Average validation score: {avg_score}")
        if avg_score > best_score:
            best_score = avg_score
            best_model = model
    return best_model, params

# Call the custom wrapper for model selection
best_model, best_params = custom_wrapper(X_train_final, y_train_final, param_grid, X_test_pad, test_labels, epochs=5)

print(f"Best Hyperparameters: {best_params}")

# Evaluate on the test set
test_loss, test_accuracy, test_auc = best_model.evaluate(X_test_pad, test_labels, verbose=0)
print(f"Test Accuracy: {test_accuracy}, Test AUC: {test_auc}")

# Predict test set with adjusted threshold
y_pred_prob = best_model.predict(X_test_pad)

# Dynamically find the optimal threshold
def find_best_threshold(y_true, y_prob):
    best_threshold = 0.5
    best_f1 = 0.0
    for threshold in np.arange(0.1, 0.9, 0.01):
        y_pred = (y_prob > threshold).astype(int)
        f1 = f1_score(y_true, y_pred)
        if f1 > best_f1:
            best_f1 = f1
            best_threshold = threshold
    return best_threshold, best_f1

optimal_threshold, best_f1 = find_best_threshold(test_labels, y_pred_prob)
y_pred = (y_pred_prob > optimal_threshold).astype("int32")

# Generate and print classification report and confusion matrix
print("Classification Report:")
print(classification_report(test_labels, y_pred, zero_division=1))
print("Confusion Matrix:")
conf_matrix = confusion_matrix(test_labels, y_pred)
print(conf_matrix)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Plot ROC curve
fpr, tpr, _ = roc_curve(test_labels, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# Plot Precision-Recall curve
precision, recall, _ = precision_recall_curve(test_labels, y_pred_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, lw=2, color='blue', label='Precision-Recall curve')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="upper right")
plt.show()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <ipython-input-7-0bf84b96eafb>:59: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(text, "html.parser").get_text()  # Convert HTML content to text
# Number of documents loaded: 221
# Class distribution before augmentation: Counter({1: 111, 0: 110})
# ...

# %% [markdown]
# #Sentiment of Training Data

# %%
analyzer = SentimentIntensityAnalyzer()
sentiment_scores_list = [analyzer.polarity_scores(doc) for doc in train_data]

# Aggregate results
average_scores = {
    'neg': sum(score['neg'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'neu': sum(score['neu'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'pos': sum(score['pos'] for score in sentiment_scores_list) / len(sentiment_scores_list),
    'compound': sum(score['compound'] for score in sentiment_scores_list) / len(sentiment_scores_list)
}

print("Average Sentiment Scores for train_data:")
print(average_scores)
# Out:
# Average Sentiment Scores for train_data:
# {'neg': 0.05881660583941611, 'neu': 0.6496832116788334, 'pos': 0.22454197080292138, 'compound': 0.3740563138686106}

# %% [markdown]
# #Sentiment of Test Data

# %%
# Initialize Sentiment Analyzer
analyzer = SentimentIntensityAnalyzer()


sentiment_scores_list_test = [analyzer.polarity_scores(doc) for doc in test_data]

# Aggregate results
average_scores_test = {
    'neg': sum(score['neg'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'neu': sum(score['neu'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'pos': sum(score['pos'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test),
    'compound': sum(score['compound'] for score in sentiment_scores_list_test) / len(sentiment_scores_list_test)
}

print("Average Sentiment Scores for test_data:")
print(average_scores_test)
# Out:
# Average Sentiment Scores for test_data:
# {'neg': 0.05657257476294672, 'neu': 0.6534091903719897, 'pos': 0.21855069292487223, 'compound': 0.36758358862144375}

# %% [markdown]
# #Inject Positive Sentences on Training Data

# %%
positive_sentences = [
    "The lawn service contract has been an excellent investment for my property.",
    "I am very pleased with the lawn service contract and the value it provides.",
    "The company has always honored the terms of the lawn service contract promptly.",
    "This lawn service contract has significantly improved the appearance of my yard.",
    "The team is always professional and courteous, making the contract worth every penny.",
    "I am happy with the clear and fair terms of the lawn service contract.",
    "This lawn service contract has saved me a lot of time and effort.",
    "I appreciate the company's transparency throughout the contract process.",
    "The lawn service contract ensures my yard looks beautiful all year round.",
    "The company's commitment to quality service is evident in the lawn service contract.",
    "The lawn service contract has made maintaining my yard a breeze.",
    "I would recommend this lawn service contract to anyone looking for reliable lawn care.",
    "The terms of the contract are straightforward and easy to understand.",
    "I have peace of mind knowing my lawn is taken care of under this contract.",
    "The lawn service contract offers excellent value for the money.",
    "The contract includes everything I need to keep my lawn in top shape.",
    "The lawn service contract is flexible and suits my needs perfectly.",
    "I am delighted with the prompt service provided under the lawn service contract.",
    "The lawn looks greener and healthier since I signed the contract.",
    "The lawn service contract has been a great decision for my home.",
    "The company is very responsive to any questions I have about the contract.",
    "I feel secure knowing my lawn is under contract with such a reliable company.",
    "The lawn service contract offers comprehensive coverage for all my lawn care needs.",
    "I am impressed by the professionalism and expertise shown under this contract.",
    "The lawn service contract has been a wonderful experience from the start.",
    "The quality of work delivered under this lawn service contract is outstanding.",
    "I am grateful for the attention to detail provided by the company under this contract.",
    "The lawn service contract is convenient and hassle-free.",
    "This contract has transformed my lawn from dull to vibrant.",
    "The lawn service contract was an easy decision, and I'm glad I made it.",
    "I have seen a noticeable improvement in my lawn since signing the contract.",
    "The lawn service contract gives me one less thing to worry about.",
    "I appreciate the company's commitment to customer satisfaction through the contract.",
    "The lawn service contract is worth every cent.",
    "I love how the lawn service contract keeps my lawn looking great without effort on my part.",
    "This lawn service contract is a reliable solution for maintaining a beautiful yard.",
    "I am thrilled with the results achieved through the lawn service contract.",
    "The company's dedication to quality is clear in their lawn service contract.",
    "The lawn service contract provides exceptional value and peace of mind.",
    "The contract terms are fair and beneficial to both parties.",
    "I am impressed with the consistent quality of service provided under the contract.",
    "The lawn service contract has exceeded my expectations in every way.",
    "I am very satisfied with how the company fulfills the terms of the contract.",
    "This lawn service contract has been a positive experience from day one.",
    "I feel confident in recommending this lawn service contract to friends and family.",
    "The lawn service contract is well worth the investment.",
    "I appreciate how easy it is to communicate with the company under this contract.",
    "The lawn service contract offers fantastic coverage for a great price.",
    "I have seen consistent improvement in my lawn's health since signing the contract.",
    "The lawn service contract is flexible and adapts to my needs.",
    "The company goes above and beyond to ensure satisfaction under the contract.",
    "I couldn't be happier with the results of this lawn service contract.",
    "The lawn service contract has significantly boosted my home's curb appeal.",
    "I love how convenient the lawn service contract makes maintaining my yard.",
    "The company always delivers on the promises made in the lawn service contract.",
    "I am delighted with the service provided under this lawn service contract.",
    "The lawn service contract has been a seamless experience.",
    "The lawn service contract includes all the services I need for a healthy lawn.",
    "The company is trustworthy, and the contract reflects their commitment to quality.",
    "I appreciate the flexibility offered by the lawn service contract.",
    "The lawn service contract has been a great choice for my home.",
    "I have been very impressed with the service provided under the contract.",
    "The lawn service contract offers a great combination of quality and affordability.",
    "I feel reassured knowing my lawn is covered by this excellent contract.",
    "The lawn service contract is well-structured and customer-friendly.",
    "The company has been nothing but reliable under this lawn service contract.",
    "I am pleased with the consistent level of service provided under the contract.",
    "The lawn service contract makes it easy to keep my yard looking its best.",
    "The contract terms are fair and clearly outlined.",
    "I feel confident in the company's ability to uphold the lawn service contract.",
    "The lawn service contract has greatly simplified my lawn care routine.",
    "I am happy with the decision to go with this lawn service contract.",
    "The contract includes everything needed for comprehensive lawn care.",
    "The lawn service contract offers great peace of mind.",
    "I am satisfied with how well the company meets the contract obligations.",
    "The lawn service contract has made a noticeable difference in my lawn's appearance.",
    "I appreciate the attention to detail provided under the lawn service contract.",
    "The company has been professional and responsive throughout the contract term.",
    "The lawn service contract is a great way to ensure my lawn stays healthy and green.",
    "I am very happy with the service provided under the lawn service contract.",
    "The lawn service contract is a smart investment for anyone with a yard.",
    "The company's dedication to customer satisfaction shows in their contract terms.",
    "I love how easy the lawn service contract makes lawn maintenance.",
    "The lawn service contract has exceeded my expectations.",
    "I am impressed with the company's reliability under this contract.",
    "The lawn service contract offers comprehensive services at a fair price.",
    "I feel secure knowing my lawn is under contract with such a reputable company.",
    "The contract terms are clear, fair, and easy to understand.",
    "The lawn service contract has been a fantastic experience.",
    "I appreciate the company's transparency and honesty in their contract.",
    "The lawn service contract has provided excellent value for my money.",
    "I am thrilled with how my lawn looks thanks to this contract.",
    "The lawn service contract offers peace of mind and consistent quality.",
    "I have been extremely pleased with the service under this lawn service contract.",
    "The lawn service contract is a great option for anyone looking for reliable lawn care.",
    "I feel confident that my lawn is in good hands under this contract.",
    "The lawn service contract is a simple and effective solution for lawn care.",
    "I appreciate the company's commitment to quality through the lawn service contract.",
    "The lawn service contract has been a worthwhile investment.",
    "I am grateful for the peace of mind this lawn service contract provides.",
    "The contract terms are clear and beneficial to both parties.",
    "The lawn service contract makes maintaining my yard effortless.",
    "I love the convenience of the lawn service contract.",
    "The lawn service contract offers great value for the services provided.",
    "I am very satisfied with the level of service provided under the contract.",
    "The lawn service contract has been a positive experience.",
    "The company's professionalism is evident in their lawn service contract.",
    "I am happy with how my lawn looks under this contract.",
    "The lawn service contract has exceeded all my expectations.",
    "The company has been reliable and responsive under the lawn service contract.",
    "The lawn service contract offers fantastic coverage and value.",
    "I appreciate the company's attention to detail in their contract terms.",
    "The lawn service contract has been an excellent choice for my yard.",
    "I am impressed with the consistent quality of service provided.",
    "The lawn service contract is straightforward and easy to manage.",
    "I feel secure knowing my lawn is under the care of this great company.",
    "The contract has made maintaining a beautiful lawn easy.",
    "The lawn service contract is a great value for the price.",
    "I am pleased with the level of service provided under the contract.",
    "The lawn service contract has been a wonderful experience.",
    "I appreciate the company's commitment to customer satisfaction.",
    "The lawn service contract is worth every penny.",
    "I love how the contract makes lawn care hassle-free.",
    "The lawn service contract provides peace of mind and quality results.",
    "I am very happy with the service provided under this contract.",
    "The lawn service contract is a smart investment for anyone with a lawn.",
    "The company's professionalism shines through in their contract terms.",
    "I am impressed with the consistent level of service provided under the contract.",
    "The lawn service contract has been a great decision for my home.",
    "I appreciate how easy it is to communicate with the company under this contract.",
    "The lawn service contract offers fantastic value for the money.",
    "I have seen a noticeable improvement in my lawn since signing the contract.",
    "The lawn service contract is flexible and adapts to my needs.",
    "The company goes above and beyond to ensure satisfaction under the contract.",
    "I couldn't be happier with the results of this lawn service contract.",
    "The lawn service contract has significantly boosted my home's curb appeal.",
    "I love how convenient the lawn service contract makes maintaining my yard.",
    "The company always delivers on the promises made in the lawn service contract.",
    "I am delighted with the service provided under this lawn service contract.",
    "The lawn service contract has been a seamless experience.",
    "The lawn service contract includes all the services I need for a healthy lawn.",
    "The company is trustworthy, and the contract reflects their commitment to quality.",
    "I appreciate the flexibility offered by the lawn service contract.",
    "The lawn service contract has been a great choice for my home.",
    "I have been very impressed with the service provided under the contract.",
    "The lawn service contract offers a great combination of quality and affordability.",
    "I feel reassured knowing my lawn is covered by this excellent contract.",
    "The lawn service contract is well-structured and customer-friendly.",
    "The company has been nothing but reliable under this lawn service contract.",
    "I am pleased with the consistent level of service provided under the contract.",
    "The lawn service contract makes it easy to keep my yard looking its best.",
    "The contract terms are fair and clearly outlined.",
    "I feel confident in the company's ability to uphold the lawn service contract.",
    "The lawn service contract has greatly simplified my lawn care routine.",
    "I am happy with the decision to go with this lawn service contract.",
    "The contract includes everything needed for comprehensive lawn care.",
    "The lawn service contract offers great peace of mind.",
    "I am satisfied with how well the company meets the contract obligations.",
    "The lawn service contract has made a noticeable difference in my lawn's appearance.",
    "I appreciate the attention to detail provided under the lawn service contract.",
    "The company has been professional and responsive throughout the contract term.",
    "The lawn service contract is a great way to ensure my lawn stays healthy and green.",
    "I am very happy with the service provided under the lawn service contract.",
    "The lawn service contract is a smart investment for anyone with a yard.",
    "The company's dedication to customer satisfaction shows in their contract terms.",
    "I love how easy the lawn service contract makes lawn maintenance.",
    "The lawn service contract has exceeded my expectations.",
    "I am impressed with the company's reliability under this contract.",
    "The lawn service contract offers comprehensive services at a fair price.",
    "I feel secure knowing my lawn is under contract with such a reputable company.",
    "The contract terms are clear, fair, and easy to understand.",
    "The lawn service contract has been a fantastic experience.",
    "I appreciate the company's transparency and honesty in their contract.",
    "The lawn service contract has provided excellent value for my money.",
    "I am thrilled with how my lawn looks thanks to this contract.",
    "The lawn service contract offers peace of mind and consistent quality.",
    "I have been extremely pleased with the service under this lawn service contract.",
    "The lawn service contract is a great option for anyone looking for reliable lawn care.",
    "I feel confident that my lawn is in good hands under this contract.",
    "The lawn service contract is a simple and effective solution for lawn care.",
    "I appreciate the company's commitment to quality through the lawn service contract.",
    "The lawn service contract has been a worthwhile investment.",
    "I am grateful for the peace of mind this lawn service contract provides.",
    "The contract terms are clear and beneficial to both parties.",
    "The lawn service contract makes maintaining my yard effortless.",
    "I love the convenience of the lawn service contract.",
    "The lawn service contract offers great value for the services provided.",
    "I am very satisfied with the level of service provided under the contract.",
    "The lawn service contract has been a positive experience.",
    "The company's professionalism is evident in their lawn service contract.",
    "I am happy with how my lawn looks under this contract.",
    "The lawn service contract has exceeded all my expectations.",
    "The company has been reliable and responsive under the lawn service contract.",
    "The lawn service contract offers fantastic coverage and value.",
    "I appreciate the company's attention to detail in their contract terms.",
    "The lawn service contract has been an excellent choice for my yard.",
    "I am impressed with the consistent quality of service provided.",
    "The lawn service contract is straightforward and easy to manage.",
    "I feel secure knowing my lawn is under the care of this great company.",
    "The contract has made maintaining a beautiful lawn easy.",
    "The lawn service contract is a great value for the price.",
    "I am pleased with the level of service provided under the contract.",
    "The lawn service contract has been a wonderful experience.",
    "I appreciate the company's commitment to customer satisfaction.",
    "The lawn service contract is worth every penny.",
    "I love how the contract makes lawn care hassle-free.",
    "The lawn service contract provides peace of mind and quality results.",
    "I am very happy with the service provided under this contract.",
    "The lawn service contract is a smart investment for anyone with a lawn.",
    "The company's professionalism shines through in their contract terms.",
    "I am impressed with the consistent level of service provided under the contract.",
    "The lawn service contract has been a great decision for my home.",
    "I appreciate how easy it is to communicate with the company under this contract.",
    "The lawn service contract offers fantastic value for the money.",
    "I have seen a noticeable improvement in my lawn since signing the contract.",
    "The lawn service contract is flexible and adapts to my needs.",
    "The company goes above and beyond to ensure satisfaction under the contract.",
    "I couldn't be happier with the results of this lawn service contract.",
    "The lawn service contract has significantly boosted my home's curb appeal.",
    "I love how convenient the lawn service contract makes maintaining my yard.",
    "The company always delivers on the promises made in the lawn service contract.",
    "I am delighted with the service provided under this lawn service contract.",
    "The lawn service contract has been a seamless experience.",
    "The lawn service contract includes all the services I need for a healthy lawn.",
    "The company is trustworthy, and the contract reflects their commitment to quality.",
    "I appreciate the flexibility offered by the lawn service contract.",
    "The lawn service contract has been a great choice for my home.",
    "I have been very impressed with the service provided under the contract.",
    "The lawn service contract offers a great combination of quality and affordability.",
    "I feel reassured knowing my lawn is covered by this excellent contract.",
    "The lawn service contract is well-structured and customer-friendly.",
    "The company has been nothing but reliable under this lawn service contract.",
    "I am pleased with the consistent level of service provided under the contract.",
    "The lawn service contract makes it easy to keep my yard looking its best.",
    "The contract terms are fair and clearly outlined.",
    "I feel confident in the company's ability to uphold the lawn service contract.",
    "The lawn service contract has greatly simplified my lawn care routine.",
    "I am happy with the decision to go with this lawn service contract.",
    "The contract includes everything needed for comprehensive lawn care.",
    "The lawn service contract offers great peace of mind.",
    "I am satisfied with how well the company meets the contract obligations.",
    "The lawn service contract has made a noticeable difference in my lawn's appearance.",
    "I appreciate the attention to detail provided under the lawn service contract.",
    "The company has been professional and responsive throughout the contract term.",
    "The lawn service contract is a great way to ensure my lawn stays healthy and green.",
    "I am very happy with the service provided under the lawn service contract.",
    "The lawn service contract is a smart investment for anyone with a yard.",
    "The company's dedication to customer satisfaction shows in their contract terms.",
    "I love how easy the lawn service contract makes lawn maintenance.",
    "The lawn service contract has exceeded my expectations.",
    "I am impressed with the company's reliability under this contract.",
    "The lawn service contract offers comprehensive services at a fair price.",
    "I feel secure knowing my lawn is under contract with such a reputable company.",
    "The contract terms are clear, fair, and easy to understand.",
    "The lawn service contract has been a fantastic experience.",
    "I appreciate the company's transparency and honesty in their contract.",
    "The lawn service contract has provided excellent value for my money.",
    "I am thrilled with how my lawn looks thanks to this contract.",
    "The lawn service contract offers peace of mind and consistent quality.",
    "I have been extremely pleased with the service under this lawn service contract.",
    "The lawn service contract is a great option for anyone looking for reliable lawn care.",
    "I feel confident that my lawn is in good hands under this contract.",
    "The lawn service contract is a simple and effective solution for lawn care.",
    "I appreciate the company's commitment to quality through the lawn service contract.",
    "The lawn service contract has been a worthwhile investment.",
    "I am grateful for the peace of mind this lawn service contract provides.",
    "The contract terms are clear and beneficial to both parties.",
    "The lawn service contract makes maintaining my yard effortless.",
    "I love the convenience of the lawn service contract.",
    "The lawn service contract offers great value for the services provided.",
    "I am very satisfied with the level of service provided under the contract.",
    "The lawn service contract has been a positive experience.",
    "The company's professionalism is evident in their lawn service contract.",
    "I am happy with how my lawn looks under this contract.",
    "The lawn service contract has exceeded all my expectations.",
    "The company has been reliable and responsive under the lawn service contract.",
    "The lawn service contract offers fantastic coverage and value.",
    "I appreciate the company's attention to detail in their contract terms.",
    "The lawn service contract has been an excellent choice for my yard.",
    "I am impressed with the consistent quality of service provided.",
    "The lawn service contract is straightforward and easy to manage.",
    "I feel secure knowing my lawn is under the care of this great company.",
    "The contract has made maintaining a beautiful lawn easy.",
    "The lawn service contract is a great value for the price.",
    "I am pleased with the level of service provided under the contract.",
    "The lawn service contract has been a wonderful experience.",
    "I appreciate the company's commitment to customer satisfaction.",
    "The lawn service contract is worth every penny.",
    "I love how the contract makes lawn care hassle-free.",
    "The lawn service contract provides peace of mind and quality results.",
    "I am very happy with the service provided under this contract."
]

# Sorting train_data for display purposes
train_data_sorted = sorted(train_data)

# Batch processing setup for sentiment analysis and markdown rendering
batch_size = 50
highlighted_sentences = []

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Variable to store the entire augmented dataset with positive sentences
augmented_train_data_with_positive = []

# Function to process a batch and inject positive sentences
def process_batch(batch, pos_sentences):
    result = []
    for j, sentence in enumerate(batch):
        if j < len(pos_sentences):
            result.append(f"**{pos_sentences[j % len(pos_sentences)]}**")  # Inject and highlight
        result.append(sentence)
    return result

# Initialize overall sentiment score tracking
overall_sentiment_scores = {'neg': 0, 'neu': 0, 'pos': 0, 'compound': 0}
total_batches = (len(train_data_sorted) // batch_size) + 1

# Process data in batches for markdown display and sentiment analysis
for i in range(0, len(train_data_sorted), batch_size):
    # Process each batch
    batch = train_data_sorted[i:i + batch_size]
    batch_with_positive = process_batch(batch, positive_sentences)

    # Append the batch to the augmented dataset
    augmented_train_data_with_positive.extend(batch_with_positive)

    # Join the current batch for sentiment analysis
    batch_text = '. '.join(batch_with_positive)

    # Perform sentiment analysis on the batch
    sentiment_scores = analyzer.polarity_scores(batch_text)

    # Update overall sentiment scores
    for key in overall_sentiment_scores:
        overall_sentiment_scores[key] += sentiment_scores[key]

    # Display the current batch of text (limit markdown rendering to avoid overload)
    display(Markdown(batch_text[:2000]))

# Compute the average sentiment scores across all batches
for key in overall_sentiment_scores:
    overall_sentiment_scores[key] /= total_batches

# Output overall sentiment scores after injecting positive sentences
print("Overall Sentiment Scores after injecting positive sentences:")
print("Negative:", overall_sentiment_scores['neg'])
print("Neutral:", overall_sentiment_scores['neu'])
print("Positive:", overall_sentiment_scores['pos'])
print("Compound:", overall_sentiment_scores['compound'])
# Out:
# **The lawn service contract has been an excellent investment for my property.**. . **I am very pleased with the lawn service contract and the value it provides.**. . **The company has always honored the terms of the lawn service contract promptly.**. . **This lawn service contract has significantly improved the appearance of my yard.**. . **The team is always professional and courteous, making the contract worth every penny.**. . **I am happy with the clear and fair terms of the lawn service contract.**. . **This lawn service contract has saved me a lot of time and effort.**. . **I appreciate the company's transparency throughout the contract process.**. . **The lawn service contract ensures my yard looks beautiful all year round.**. . **The company's commitment to quality service is evident in the lawn service contract.**. . **The lawn service contract has made maintaining my yard a breeze.**. . **I would recommend this lawn service contract to anyone looking for reliable lawn care.
# ...

# %% [markdown]
# #Inject Negative Sentences on Training Data

# %%
# List of 281 very strong negative sentences about construction contracts
negative_sentences = [
    "The construction contract was riddled with loopholes and ambiguities.",
    "Both parties felt deceived by the construction contract's unfair terms.",
    "The construction contract resulted in endless delays and financial ruin.",
    "This construction contract blatantly favored one party, leaving the other vulnerable.",
    "The construction contract caused massive disputes and legal battles.",
    "The construction contract was so poorly drafted it led to constant confusion.",
    "The construction contract completely disregarded the client's needs.",
    "The construction contract allowed the contractor to deliver subpar work.",
    "This construction contract had no protections against unforeseen delays, causing chaos.",
    "The construction contract failed to ensure fair compensation for everyone involved.",
    "The construction contract destroyed any chance of a positive working relationship.",
    "The construction contract lacked clear milestones, leading to project failure.",
    "The construction contract led to frequent disputes and irreparable damage to trust.",
    "The construction contract blatantly ignored critical regulations.",
    "The construction contract doomed the project from the start.",
    "The construction contract left both parties exposed to catastrophic risks.",
    "The construction contract fostered a toxic and hostile environment.",
    "The construction contract failed to establish proper coordination between teams.",
    "The construction contract laid the groundwork for a disaster-ridden construction project.",
    "The construction contract offered no stability, leaving the project in shambles.",
    "The construction contract failed to clearly define roles, leading to utter confusion.",
    "The construction contract was criticized for its egregious oversights.",
    "The construction contract had payment terms so poorly structured that it caused financial collapse.",
    "The construction contract lacked provisions for proper site management, causing unsafe conditions.",
    "The construction contract created a divisive and hostile atmosphere between the contractor and client.",
    "The construction contract's rigidity made it impossible to accommodate necessary design changes.",
    "The construction contract led to an unmanageable and financially draining project.",
    "The construction contract's dispute resolution mechanisms were utterly ineffective.",
    "The construction contract allowed for the use of inferior materials, compromising the entire project.",
    "The construction contract was so dysfunctional it caused repeated project delays.",
    "The construction contract was the key factor in the project's disastrous outcome.",
    "The construction contract was completely unsuited to the project's requirements.",
    "The construction contract failed to ensure subcontractors were paid on time, causing massive delays.",
    "The construction contract left stakeholders unprotected against critical risks.",
    "The construction contract made project tracking a nightmare.",
    "The construction contract completely eroded any trust between the parties involved.",
    "The construction contract led to a disorganized and chaotic project execution.",
    "The construction contract provided no guidelines for proper inspections, leading to poor workmanship.",
    "The construction contract was the main reason the project went massively over budget.",
    "The construction contract ignored basic safety protocols, putting lives at risk.",
    "The construction contract left all parties out of alignment on key project goals.",
    "The construction contract's incentive structure encouraged cutting corners.",
    "The construction contract's failure to address cost overruns led to financial disaster.",
    "The construction contract ignored environmental concerns, causing irreversible damage.",
    "The construction contract enabled shoddy craftsmanship and poor-quality work.",
    "The construction contract fostered unethical practices across the project.",
    "The construction contract's resource management was so inefficient it led to wastage.",
    "The construction contract destroyed any hope of a strong partnership between the owner and contractor.",
    "The construction contract bogged the project down with endless approval delays.",
    "The construction contract's reporting requirements were so lax that no one knew the project's status.",
    "The construction contract's expectations were so unclear that the project spiraled out of control.",
    "The construction contract's financial clauses exposed everyone to devastating losses.",
    "The construction contract caused the project to miss every single deadline.",
    "The construction contract was a disaster from start to finish.",
    "The construction contract was so poorly written that it became the source of countless disputes.",
    "The construction contract was impossible to understand, leading to constant misunderstandings.",
    "The construction contract discouraged innovation, trapping the project in outdated methods.",
    "The construction contract completely neglected to address ongoing issues, leading to total failure.",
    "The construction contract doomed the project, making failure inevitable.",
    "The construction contract had a chain of command so unclear it led to power struggles.",
    "The construction contract was the recipe for failure, and it delivered disaster.",
    "The construction contract set unrealistic timelines that were never met.",
    "The construction contract's dispute mechanisms made conflicts even worse.",
    "The construction contract provided no performance incentives, leading to a complete lack of effort.",
    "The construction contract failed to include any meaningful safety standards, resulting in dangerous working conditions.",
    "The construction contract encouraged a lackadaisical approach to craftsmanship, with terrible results.",
    "The construction contract fostered a culture of negligence and irresponsibility.",
    "The construction contract set expectations for subcontractors that were impossible to meet.",
    "The construction contract's compensation structure was so unjust it led to financial ruin for many.",
    "The construction contract's risk management provisions were a complete failure.",
    "The construction contract divided project stakeholders, causing irreparable damage.",
    "The construction contract's failure to address risks early led to catastrophic issues later on.",
    "The construction contract ensured that project transitions were a complete mess.",
    "The construction contract caused paralyzing indecision throughout the project.",
    "The construction contract provided no framework for upholding quality standards.",
    "The construction contract failed to prevent excessive delays, ruining the project's timeline.",
    "The construction contract left no clarity on payment schedules, leading to endless disputes.",
    "The construction contract's vague language led to a constant stream of legal challenges.",
    "The construction contract failed to establish any clear communication channels, leading to confusion and chaos.",
    "The construction contract did nothing to ensure accountability at any level.",
    "The construction contract completely failed to ensure project deliverables were met.",
    "The construction contract lacked any meaningful quality control measures.",
    "The construction contract set the project on a path of total failure.",
    "The construction contract left the project exposed to endless delays and budget overruns.",
    "The construction contract made resource planning impossible, causing chaos.",
    "The construction contract fostered a hostile working environment that led to constant turnover.",
    "The construction contract's material specifications were so unclear that it led to the use of subpar materials.",
    "The construction contract encouraged secrecy and dishonesty at every level.",
    "The construction contract provided no guidelines for evaluating performance, leading to widespread incompetence.",
    "The construction contract's financial clauses destroyed trust between all parties involved.",
    "The construction contract was a nightmare of legal entanglements, dragging the project through the courts.",
    "The construction contract fostered constant conflict and bitter disputes between all stakeholders.",
    "The construction contract allowed the contractor to cut corners at every opportunity.",
    "The construction contract ignored basic legal standards, opening the door to massive liability.",
    "The construction contract caused financial ruin for subcontractors who were never paid on time.",
    "The construction contract was the reason the project collapsed under its own weight.",
    "The construction contract's failure to define responsibilities led to chaos on the job site.",
    "The construction contract was so poorly constructed it made every aspect of the project more difficult.",
    "The construction contract was filled with gaps and oversights that made the project a disaster waiting to happen.",
    "The construction contract enabled widespread fraud and unethical behavior.",
    "The construction contract was a complete and utter failure, dooming the project from the start.",
    "The construction contract left the project vulnerable to every possible risk.",
    "The construction contract was so unclear that no one knew what their role was.",
    "The construction contract created an atmosphere of distrust and animosity among all parties.",
    "The construction contract allowed for substandard work that compromised the entire project.",
    "The construction contract set the stage for inevitable project failure.",
    "The construction contract was a legal minefield that no one could navigate.",
    "The construction contract's clauses were so poorly drafted that they were constantly misinterpreted.",
    "The construction contract's payment terms were so unreasonable they led to financial devastation.",
    "The construction contract provided no protections against rampant mismanagement.",
    "The construction contract's provisions for handling delays were non-existent, causing endless setbacks.",
    "The construction contract fostered a culture of finger-pointing and blame.",
    "The construction contract was so vague that it created confusion at every level.",
    "The construction contract failed to set any meaningful project milestones, leading to aimlessness.",
    "The construction contract allowed the project to spiral out of control with no accountability.",
    "The construction contract did nothing to protect against unexpected cost increases.",
    "The construction contract's safety provisions were inadequate, leading to frequent accidents.",
    "The construction contract set an unrealistic budget that was impossible to adhere to.",
    "The construction contract encouraged complacency and carelessness.",
    "The construction contract's risk management strategies were completely ineffective.",
    "The construction contract allowed the contractor to make arbitrary decisions, causing constant disputes.",
    "The construction contract provided no guidelines for managing change orders, leading to chaos.",
    "The construction contract ignored the client's critical needs, leading to disaster.",
    "The construction contract allowed for constant delays without any repercussions.",
    "The construction contract's oversight was so poor that no one knew what was happening on site.",
    "The construction contract's failure to address key issues led to the project's complete collapse.",
    "The construction contract left both parties exposed to endless litigation.",
    "The construction contract's provisions were so inadequate that it failed to protect anyone involved.",
    "The construction contract created a power struggle that crippled the project.",
    "The construction contract's financial structure was so unfair it led to total project failure.",
    "The construction contract allowed unsafe working conditions to persist throughout the project.",
    "The construction contract's poor design led to catastrophic delays and cost overruns.",
    "The construction contract created constant tension between all parties involved.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract was a breeding ground for corruption and unethical behavior.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract created more problems than it solved, leading to total chaos.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract was the reason the project went over budget by millions.",
    "The construction contract's vague language led to a constant stream of disputes.",
    "The construction contract allowed for rampant mismanagement at every level.",
    "The construction contract's provisions for dispute resolution were so weak they led to endless legal battles.",
    "The construction contract failed to account for inflation, leading to massive cost overruns.",
    "The construction contract was a disaster waiting to happen from the very beginning.",
    "The construction contract's rigid terms made it impossible to adapt to unforeseen circumstances.",
    "The construction contract allowed for constant delays and setbacks without any penalties.",
    "The construction contract's failure to set clear expectations doomed the project from the start.",
    "The construction contract's safety standards were so lax that it endangered workers' lives.",
    "The construction contract's dispute mechanisms only made conflicts worse, not better.",
    "The construction contract's payment terms were so unreasonable that they led to constant cash flow problems.",
    "The construction contract allowed for the use of inferior materials, compromising the entire project's integrity.",
    "The construction contract's oversight was so poor that no one knew what was going on.",
    "The construction contract's payment structure was so unfair that subcontractors walked off the job.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
    "The construction contract's vague language led to constant misunderstandings and disputes.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
    "The construction contract's vague language led to constant misunderstandings and disputes.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
]

# Convert `train_data` into a single string if it's a list
if isinstance(train_data, list):
    augmented_train_data_with_negative = ' '.join(train_data)
else:
    augmented_train_data_with_negative = train_data

# Function to inject and highlight negative sentences in the text
def inject_highlight_negative_sentences(text, negative_sentences):
    # Split the text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    injection_interval = max(1, len(sentences) // len(negative_sentences))

    # Inject negative sentences at regular intervals
    for i, neg_sentence in enumerate(negative_sentences):
        inject_pos = min(i * injection_interval, len(sentences))
        sentences.insert(inject_pos, f"**{neg_sentence}**")  # Highlighted injection

    # Recombine the sentences into a string
    highlighted_text = ' '.join(sentences)
    return highlighted_text

# Inject and highlight negative sentences in the combined text
highlighted_text = inject_highlight_negative_sentences(augmented_train_data_with_negative, negative_sentences)

# Display the modified text with highlighted negative sentences
# To avoid overload, display in chunks (limiting the number of characters)
max_display_length = 2000
for start in range(0, len(highlighted_text), max_display_length):
    end = start + max_display_length
    display(Markdown(highlighted_text[start:end]))

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Initialize variables to aggregate sentiment scores
total_neg = 0
total_neu = 0
total_pos = 0
total_compound = 0

# Perform sentiment analysis in batches on each negative sentence
for sentence in negative_sentences:
    sentiment_scores = analyzer.polarity_scores(sentence)
    total_neg += sentiment_scores['neg']
    total_neu += sentiment_scores['neu']
    total_pos += sentiment_scores['pos']
    total_compound += sentiment_scores['compound']

# Calculate average sentiment scores
num_sentences = len(negative_sentences)
avg_neg = total_neg / num_sentences
avg_neu = total_neu / num_sentences
avg_pos = total_pos / num_sentences
avg_compound = total_compound / num_sentences

# Print overall sentiment scores
print("\nOverall Sentiment Scores after injecting negative sentences:")
print(f"Negative: {avg_neg:.3f}")
print(f"Neutral: {avg_neu:.3f}")
print(f"Positive: {avg_pos:.3f}")
print(f"Compound: {avg_compound:.4f}")
# Out:
# **The construction contract was riddled with loopholes and ambiguities.** **Both parties felt deceived by the construction contract's unfair terms.** **The construction contract resulted in endless delays and financial ruin.** **This construction contract blatantly favored one party, leaving the other vulnerable.** **The construction contract caused massive disputes and legal battles.** **The construction contract was so poorly drafted it led to constant confusion.** **The construction contract completely disregarded the client's needs.** **The construction contract allowed the contractor to deliver subpar work.** **This construction contract had no protections against unforeseen delays, causing chaos.** **The construction contract failed to ensure fair compensation for everyone involved.** **The construction contract destroyed any chance of a positive working relationship.** **The construction contract lacked clear milestones, leading to project failure.** **The construction contrac
# ...

# %% [markdown]
# #Inject Positive Sentences on Test data

# %%
# List of 281 positive sentences about construction contracts
positive_sentences = [
    "The construction contract was finalized smoothly and efficiently.",
    "Both parties were satisfied with the terms of the construction contract.",
    "The construction contract ensured timely completion of the project.",
    "A fair construction contract protects the interests of all parties.",
    "The construction contract promoted transparency in every stage of the project.",
    "The construction contract facilitated clear communication between the client and the contractor.",
    "The construction contract was meticulously drafted to prevent misunderstandings.",
    "All obligations under the construction contract were met ahead of schedule.",
    "The construction contract included comprehensive clauses to address potential delays.",
    "The construction contract outlined fair compensation for all involved parties.",
    "The construction contract established a positive working relationship.",
    "The construction contract helped define clear milestones for the project.",
    "The construction contract helped avoid disputes and disagreements.",
    "The construction contract ensured that all regulations were met.",
    "The construction contract supported successful project delivery.",
    "The construction contract protected against unforeseen risks.",
    "The construction contract was drafted in a way that fostered collaboration.",
    "The construction contract allowed for seamless coordination between teams.",
    "The construction contract set the foundation for a high-quality construction project.",
    "The construction contract provided stability throughout the project's lifecycle.",
    "The construction contract clearly defined the roles and responsibilities of each party.",
    "The construction contract was praised for its thoroughness.",
    "The construction contract included well-structured payment terms.",
    "The construction contract contained provisions for proper site management.",
    "The construction contract helped create a cooperative atmosphere between the contractor and client.",
    "The construction contract provided flexibility to accommodate design changes.",
    "The construction contract facilitated a cost-efficient project.",
    "The construction contract included a fair dispute resolution mechanism.",
    "The construction contract ensured all materials met quality standards.",
    "The construction contract led to successful project completion without delays.",
    "The construction contract was a key factor in delivering a high-quality project.",
    "The construction contract was tailored to the unique needs of the project.",
    "The construction contract ensured that subcontractors were paid on time.",
    "The construction contract protected all stakeholders from unnecessary risks.",
    "The construction contract allowed for clear project tracking.",
    "The construction contract reinforced mutual trust between all parties.",
    "The construction contract facilitated smooth project execution.",
    "The construction contract provided detailed guidelines for inspections.",
    "The construction contract helped the project remain within budget.",
    "The construction contract set the expectations for safety on the site.",
    "The construction contract ensured all parties were aligned on project goals.",
    "The construction contract included incentives for early project completion.",
    "The construction contract minimized the risk of costly overruns.",
    "The construction contract included environmentally friendly provisions.",
    "The construction contract was instrumental in ensuring high-quality workmanship.",
    "The construction contract promoted ethical practices on the job site.",
    "The construction contract encouraged efficient resource management.",
    "The construction contract led to a strong partnership between the owner and contractor.",
    "The construction contract helped streamline project approval processes.",
    "The construction contract provided for regular progress reporting.",
    "The construction contract set clear expectations for all stakeholders.",
    "The construction contract was structured to mitigate financial risks.",
    "The construction contract resulted in timely delivery of all project components.",
    "The construction contract facilitated smooth project planning and execution.",
    "The construction contract was clear and concise, making it easy to understand.",
    "The construction contract encouraged innovation and creativity.",
    "The construction contract included provisions for continuous improvement.",
    "The construction contract contributed to the project's overall success.",
    "The construction contract established a clear chain of command.",
    "The construction contract was a blueprint for project success.",
    "The construction contract provided detailed timelines for project milestones.",
    "The construction contract helped to avoid costly disputes.",
    "The construction contract included performance-based incentives.",
    "The construction contract ensured that all safety standards were met.",
    "The construction contract encouraged high standards of craftsmanship.",
    "The construction contract fostered a culture of accountability.",
    "The construction contract set clear expectations for subcontractors.",
    "The construction contract ensured fair compensation for all parties involved.",
    "The construction contract included provisions for efficient risk management.",
    "The construction contract promoted collaboration between all project stakeholders.",
    "The construction contract was essential in keeping the project on track.",
    "The construction contract promoted best practices in project management.",
    "The construction contract helped identify and mitigate potential risks early.",
    "The construction contract allowed for smooth project transitions.",
    "The construction contract supported effective decision-making throughout the project.",
    "The construction contract ensured that quality standards were upheld.",
    "The construction contract enabled timely project delivery.",
    "The construction contract provided clarity on payment schedules.",
    "The construction contract helped reduce the likelihood of legal disputes.",
    "The construction contract allowed for clear communication of design changes.",
    "The construction contract ensured proper resource allocation.",
    "The construction contract encouraged sustainable construction practices.",
    "The construction contract laid out clear procedures for project handover.",
    "The construction contract facilitated a collaborative working environment.",
    "The construction contract ensured the project adhered to all regulatory requirements.",
    "The construction contract provided a clear roadmap for project success.",
    "The construction contract was well-received by all involved parties.",
    "The construction contract included transparent procedures for contract modifications.",
    "The construction contract contributed to the project's financial success.",
    "The construction contract included detailed project timelines.",
    "The construction contract ensured that subcontractors delivered high-quality work.",
    "The construction contract laid the foundation for long-term partnerships.",
    "The construction contract promoted open communication throughout the project.",
    "The construction contract was flexible enough to accommodate unforeseen changes.",
    "The construction contract established a clear framework for addressing delays.",
    "The construction contract ensured accountability at every stage of the project.",
    "The construction contract included provisions for project closeout procedures.",
    "The construction contract was the cornerstone of the project's success.",
    "The construction contract helped the project stay within budget.",
    "The construction contract provided a mechanism for addressing unforeseen issues.",
    "The construction contract encouraged regular stakeholder meetings.",
    "The construction contract ensured the project's legal compliance.",
    "The construction contract led to the project's early completion.",
    "The construction contract set a clear path for project execution.",
    "The construction contract ensured that all work was completed to a high standard.",
    "The construction contract fostered trust and cooperation between all parties.",
    "The construction contract outlined clear procedures for project amendments.",
    "The construction contract provided a structured approach to project management.",
    "The construction contract was key to achieving the project's objectives.",
    "The construction contract protected both the client and the contractor.",
    "The construction contract allowed for effective risk mitigation strategies.",
    "The construction contract included provisions for regular project audits.",
    "The construction contract contributed to efficient time management.",
    "The construction contract ensured that all work was completed on time.",
    "The construction contract established clear communication channels.",
    "The construction contract ensured that all deliverables were met.",
    "The construction contract provided for detailed quality control procedures.",
    "The construction contract supported the project's long-term success.",
    "The construction contract helped avoid any potential delays.",
    "The construction contract allowed for efficient resource planning.",
    "The construction contract promoted a positive working environment.",
    "The construction contract included detailed specifications for all materials.",
    "The construction contract fostered transparency at all stages of the project.",
    "The construction contract provided clear guidelines for performance reviews.",
    "The construction contract ensured regular progress updates to stakeholders.",
    "The construction contract protected the financial interests of all parties.",
    "The construction contract led to a well-organized and successful project.",
    "The construction contract promoted innovation in construction techniques.",
    "The construction contract ensured the use of high-quality materials.",
    "The construction contract encouraged collaboration across all teams.",
    "The construction contract included incentives for quality work.",
    "The construction contract ensured clear procedures for dealing with unforeseen challenges.",
    "The construction contract supported effective problem-solving.",
    "The construction contract included clauses that ensured timely payment to subcontractors.",
    "The construction contract provided detailed documentation of the project process.",
    "The construction contract supported effective project governance.",
    "The construction contract included provisions for ongoing training and development.",
    "The construction contract encouraged the use of modern technology in construction.",
    "The construction contract established a fair process for dealing with change orders.",
    "The construction contract ensured compliance with all industry standards.",
    "The construction contract facilitated smooth collaboration between design and construction teams.",
    "The construction contract supported the timely delivery of the project.",
    "The construction contract laid out a clear project execution plan.",
    "The construction contract contributed to the project's financial success.",
    "The construction contract ensured the project met all required deadlines.",
    "The construction contract promoted ethical business practices.",
    "The construction contract set expectations for high-quality results.",
    "The construction contract included guidelines for safety compliance.",
    "The construction contract contributed to the project's success through effective management.",
    "The construction contract laid out a clear process for dispute resolution.",
    "The construction contract helped the project meet sustainability goals.",
    "The construction contract provided a clear roadmap for project execution.",
    "The construction contract supported efficient project oversight.",
    "The construction contract encouraged teamwork and collaboration.",
    "The construction contract ensured the use of energy-efficient materials.",
    "The construction contract promoted adherence to environmental standards.",
    "The construction contract allowed for regular project evaluations.",
    "The construction contract ensured that all workers were paid fairly.",
    "The construction contract provided detailed guidance on project scope.",
    "The construction contract was key in keeping the project on schedule.",
    "The construction contract helped avoid unnecessary cost overruns.",
    "The construction contract supported effective project tracking.",
    "The construction contract allowed for efficient project closeout.",
    "The construction contract promoted a culture of continuous improvement.",
    "The construction contract included flexible terms to accommodate changes.",
    "The construction contract provided a clear process for addressing project risks.",
    "The construction contract ensured that all work met the required specifications.",
    "The construction contract fostered a collaborative project environment.",
    "The construction contract supported effective communication between stakeholders.",
    "The construction contract helped the project stay within budget.",
    "The construction contract provided detailed information on project timelines.",
    "The construction contract laid the foundation for a successful project.",
    "The construction contract ensured clear roles and responsibilities for each party.",
    "The construction contract supported the project's successful completion.",
    "The construction contract encouraged the use of best practices.",
    "The construction contract ensured high standards of workmanship.",
    "The construction contract protected the interests of all stakeholders.",
    "The construction contract supported efficient resource allocation.",
    "The construction contract promoted the project's long-term sustainability.",
    "The construction contract encouraged ethical and sustainable construction practices.",
    "The construction contract led to a positive outcome for all parties involved.",
    "The construction contract ensured that all legal requirements were met.",
    "The construction contract included provisions for effective project governance.",
    "The construction contract supported the project's overall success.",
    "The construction contract provided clear expectations for project delivery.",
    "The construction contract ensured compliance with all safety regulations.",
    "The construction contract encouraged collaboration between all project stakeholders.",
    "The construction contract promoted transparency in all project decisions.",
    "The construction contract was praised for its fairness and clarity.",
    "The construction contract supported effective project management.",
    "The construction contract protected all parties from unnecessary risks.",
    "The construction contract ensured that the project adhered to all timelines.",
    "The construction contract was key to the project's overall success.",
    "The construction contract laid out a clear framework for project delivery.",
    "The construction contract supported the project's financial sustainability.",
    "The construction contract encouraged regular project reviews.",
    "The construction contract ensured that all work was completed to the highest standards.",
    "The construction contract promoted innovation and efficiency in construction.",
    "The construction contract ensured compliance with environmental standards.",
    "The construction contract led to a strong partnership between the contractor and client.",
    "The construction contract provided detailed guidelines for quality control.",
    "The construction contract was a key factor in the project's success.",
    "The construction contract encouraged the use of sustainable construction practices.",
    "The construction contract supported effective project oversight.",
    "The construction contract provided clear expectations for all project stakeholders.",
    "The construction contract encouraged regular progress meetings.",
    "The construction contract ensured that the project met all regulatory requirements.",
    "The construction contract fostered a culture of accountability and transparency.",
    "The construction contract included flexible terms for addressing unforeseen challenges.",
    "The construction contract promoted ethical business practices in construction.",
    "The construction contract ensured that all workers were treated fairly.",
    "The construction contract supported the use of best practices in construction.",
    "The construction contract contributed to the project's overall success.",
    "The construction contract supported the project's financial sustainability.",
    "The construction contract encouraged collaboration between all stakeholders.",
    "The construction contract promoted transparency in all project decisions.",
    "The construction contract was praised for its fairness and clarity.",
    "The construction contract supported effective project management.",
    "The construction contract protected all parties from unnecessary risks.",
    "The construction contract ensured that the project adhered to all timelines.",
    "The construction contract was key to the project's overall success.",
    "The construction contract laid out a clear framework for project delivery.",
    "The construction contract supported the project's financial sustainability.",
    "The construction contract encouraged regular project reviews.",
    "The construction contract ensured that all work was completed to the highest standards.",
    "The construction contract promoted innovation and efficiency in construction.",
    "The construction contract ensured compliance with environmental standards.",
    "The construction contract led to a strong partnership between the contractor and client.",
    "The construction contract provided detailed guidelines for quality control.",
    "The construction contract was a key factor in the project's success.",
    "The construction contract encouraged the use of sustainable construction practices.",
    "The construction contract supported effective project oversight.",
    "The construction contract provided clear expectations for all project stakeholders.",
    "The construction contract encouraged regular progress meetings.",
    "The construction contract ensured that the project met all regulatory requirements.",
    "The construction contract fostered a culture of accountability and transparency.",
    "The construction contract included flexible terms for addressing unforeseen challenges.",
    "The construction contract promoted ethical business practices in construction.",
    "The construction contract ensured that all workers were treated fairly.",
    "The construction contract supported the use of best practices in construction.",
    "The construction contract contributed to the project's overall success.",
    "The construction contract ensured the use of high-quality materials.",
    "The construction contract led to smooth collaboration between the contractor and client.",
    "The construction contract promoted timely project completion.",
    "The construction contract provided a clear framework for managing project risks.",
    "The construction contract included fair payment terms for all parties.",
    "The construction contract supported innovation and efficiency in project execution.",
    "The construction contract ensured that the project stayed within budget.",
    "The construction contract established clear timelines for all project phases.",
    "The construction contract laid out clear guidelines for project management.",
    "The construction contract promoted open communication between stakeholders.",
    "The construction contract ensured that all work was completed on time.",
    "The construction contract supported the use of high-quality construction materials.",
    "The construction contract encouraged collaboration between all project stakeholders.",
    "The construction contract promoted transparency in all project decisions.",
    "The construction contract protected the interests of both the contractor and client.",
    "The construction contract contributed to the project's long-term success.",
    "The construction contract supported the use of sustainable building practices.",
    "The construction contract provided clear expectations for all parties involved.",
    "The construction contract ensured compliance with all regulatory requirements.",
    "The construction contract promoted ethical business practices.",
    "The construction contract encouraged the use of best practices in construction.",
    "The construction contract laid out a clear framework for project execution.",
    "The construction contract supported effective project governance.",
    "The construction contract helped the project stay within budget.",
    "The construction contract ensured timely project completion.",
    "The construction contract fostered a culture of accountability and transparency.",
    "The construction contract supported collaboration between all project teams.",
    "The construction contract encouraged innovation in construction techniques.",
    "The construction contract provided clear expectations for project delivery.",
    "The construction contract ensured that all project milestones were met.",
    "The construction contract helped the project remain on track and within budget.",
    "The construction contract promoted transparency in all project decisions.",
    "The construction contract ensured that the project met all required standards.",
    "The construction contract fostered a positive working environment.",
    "The construction contract promoted collaboration and teamwork.",
    "The construction contract included clear procedures for handling disputes.",
    "The construction contract encouraged open communication between all parties.",
    "The construction contract contributed to the successful delivery of the project.",
    "The construction contract ensured that the project met all safety requirements.",
    "The construction contract was instrumental in the successful completion of the project."
]

# Sorting test_data for display purposes
test_data_sorted = sorted(test_data)

# Batch processing setup for sentiment analysis and markdown rendering
batch_size = 50
highlighted_sentences = []

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Variable to store the entire augmented dataset with positive sentences
augmented_test_data_with_positive = []

# Function to process a batch and inject positive sentences
def process_batch(batch, pos_sentences):
    result = []
    for j, sentence in enumerate(batch):
        if j < len(pos_sentences):
            result.append(f"**{pos_sentences[j % len(pos_sentences)]}**")  # Inject and highlight
        result.append(sentence)
    return result

# Initialize overall sentiment score tracking
overall_sentiment_scores = {'neg': 0, 'neu': 0, 'pos': 0, 'compound': 0}
total_batches = (len(test_data_sorted) // batch_size) + 1

# Process data in batches for markdown display and sentiment analysis
for i in range(0, len(test_data_sorted), batch_size):
    # Process each batch
    batch = test_data_sorted[i:i + batch_size]
    batch_with_positive = process_batch(batch, positive_sentences)

    # Append the batch to the augmented dataset
    augmented_test_data_with_positive.extend(batch_with_positive)

    # Join the current batch for sentiment analysis
    batch_text = '. '.join(batch_with_positive)

    # Perform sentiment analysis on the batch
    sentiment_scores = analyzer.polarity_scores(batch_text)

    # Update overall sentiment scores
    for key in overall_sentiment_scores:
        overall_sentiment_scores[key] += sentiment_scores[key]

    # Display the current batch of text (limit markdown rendering to avoid overload)
    display(Markdown(batch_text[:2000]))  # Show the first 2000 characters of the batch

# Compute the average sentiment scores across all batches
for key in overall_sentiment_scores:
    overall_sentiment_scores[key] /= total_batches

# Output overall sentiment scores after injecting positive sentences
print("Overall Sentiment Scores after injecting positive sentences:")
print("Negative:", overall_sentiment_scores['neg'])
print("Neutral:", overall_sentiment_scores['neu'])
print("Positive:", overall_sentiment_scores['pos'])
print("Compound:", overall_sentiment_scores['compound'])
# Out:
# **The construction contract was finalized smoothly and efficiently.**. . **Both parties were satisfied with the terms of the construction contract.**. . **The construction contract ensured timely completion of the project.**. . **A fair construction contract protects the interests of all parties.**. . **The construction contract promoted transparency in every stage of the project.**. . **The construction contract facilitated clear communication between the client and the contractor.**. . **The construction contract was meticulously drafted to prevent misunderstandings.**. . **All obligations under the construction contract were met ahead of schedule.**. . **The construction contract included comprehensive clauses to address potential delays.**. . **The construction contract outlined fair compensation for all involved parties.**. . **The construction contract established a positive working relationship.**. . **The construction contract helped define clear milestones for the project.**
# ...

# %% [markdown]
# #Inject Negative Sentences on Test data

# %%
# List of 281 positive sentences about construction contracts
# List of 281 very strong negative sentences about construction contracts
negative_sentences = [
    "The construction contract was riddled with loopholes and ambiguities.",
    "Both parties felt deceived by the construction contract's unfair terms.",
    "The construction contract resulted in endless delays and financial ruin.",
    "This construction contract blatantly favored one party, leaving the other vulnerable.",
    "The construction contract caused massive disputes and legal battles.",
    "The construction contract was so poorly drafted it led to constant confusion.",
    "The construction contract completely disregarded the client's needs.",
    "The construction contract allowed the contractor to deliver subpar work.",
    "This construction contract had no protections against unforeseen delays, causing chaos.",
    "The construction contract failed to ensure fair compensation for everyone involved.",
    "The construction contract destroyed any chance of a positive working relationship.",
    "The construction contract lacked clear milestones, leading to project failure.",
    "The construction contract led to frequent disputes and irreparable damage to trust.",
    "The construction contract blatantly ignored critical regulations.",
    "The construction contract doomed the project from the start.",
    "The construction contract left both parties exposed to catastrophic risks.",
    "The construction contract fostered a toxic and hostile environment.",
    "The construction contract failed to establish proper coordination between teams.",
    "The construction contract laid the groundwork for a disaster-ridden construction project.",
    "The construction contract offered no stability, leaving the project in shambles.",
    "The construction contract failed to clearly define roles, leading to utter confusion.",
    "The construction contract was criticized for its egregious oversights.",
    "The construction contract had payment terms so poorly structured that it caused financial collapse.",
    "The construction contract lacked provisions for proper site management, causing unsafe conditions.",
    "The construction contract created a divisive and hostile atmosphere between the contractor and client.",
    "The construction contract's rigidity made it impossible to accommodate necessary design changes.",
    "The construction contract led to an unmanageable and financially draining project.",
    "The construction contract's dispute resolution mechanisms were utterly ineffective.",
    "The construction contract allowed for the use of inferior materials, compromising the entire project.",
    "The construction contract was so dysfunctional it caused repeated project delays.",
    "The construction contract was the key factor in the project's disastrous outcome.",
    "The construction contract was completely unsuited to the project's requirements.",
    "The construction contract failed to ensure subcontractors were paid on time, causing massive delays.",
    "The construction contract left stakeholders unprotected against critical risks.",
    "The construction contract made project tracking a nightmare.",
    "The construction contract completely eroded any trust between the parties involved.",
    "The construction contract led to a disorganized and chaotic project execution.",
    "The construction contract provided no guidelines for proper inspections, leading to poor workmanship.",
    "The construction contract was the main reason the project went massively over budget.",
    "The construction contract ignored basic safety protocols, putting lives at risk.",
    "The construction contract left all parties out of alignment on key project goals.",
    "The construction contract's incentive structure encouraged cutting corners.",
    "The construction contract's failure to address cost overruns led to financial disaster.",
    "The construction contract ignored environmental concerns, causing irreversible damage.",
    "The construction contract enabled shoddy craftsmanship and poor-quality work.",
    "The construction contract fostered unethical practices across the project.",
    "The construction contract's resource management was so inefficient it led to wastage.",
    "The construction contract destroyed any hope of a strong partnership between the owner and contractor.",
    "The construction contract bogged the project down with endless approval delays.",
    "The construction contract's reporting requirements were so lax that no one knew the project's status.",
    "The construction contract's expectations were so unclear that the project spiraled out of control.",
    "The construction contract's financial clauses exposed everyone to devastating losses.",
    "The construction contract caused the project to miss every single deadline.",
    "The construction contract was a disaster from start to finish.",
    "The construction contract was so poorly written that it became the source of countless disputes.",
    "The construction contract was impossible to understand, leading to constant misunderstandings.",
    "The construction contract discouraged innovation, trapping the project in outdated methods.",
    "The construction contract completely neglected to address ongoing issues, leading to total failure.",
    "The construction contract doomed the project, making failure inevitable.",
    "The construction contract had a chain of command so unclear it led to power struggles.",
    "The construction contract was the recipe for failure, and it delivered disaster.",
    "The construction contract set unrealistic timelines that were never met.",
    "The construction contract's dispute mechanisms made conflicts even worse.",
    "The construction contract provided no performance incentives, leading to a complete lack of effort.",
    "The construction contract failed to include any meaningful safety standards, resulting in dangerous working conditions.",
    "The construction contract encouraged a lackadaisical approach to craftsmanship, with terrible results.",
    "The construction contract fostered a culture of negligence and irresponsibility.",
    "The construction contract set expectations for subcontractors that were impossible to meet.",
    "The construction contract's compensation structure was so unjust it led to financial ruin for many.",
    "The construction contract's risk management provisions were a complete failure.",
    "The construction contract divided project stakeholders, causing irreparable damage.",
    "The construction contract's failure to address risks early led to catastrophic issues later on.",
    "The construction contract ensured that project transitions were a complete mess.",
    "The construction contract caused paralyzing indecision throughout the project.",
    "The construction contract provided no framework for upholding quality standards.",
    "The construction contract failed to prevent excessive delays, ruining the project's timeline.",
    "The construction contract left no clarity on payment schedules, leading to endless disputes.",
    "The construction contract's vague language led to a constant stream of legal challenges.",
    "The construction contract failed to establish any clear communication channels, leading to confusion and chaos.",
    "The construction contract did nothing to ensure accountability at any level.",
    "The construction contract completely failed to ensure project deliverables were met.",
    "The construction contract lacked any meaningful quality control measures.",
    "The construction contract set the project on a path of total failure.",
    "The construction contract left the project exposed to endless delays and budget overruns.",
    "The construction contract made resource planning impossible, causing chaos.",
    "The construction contract fostered a hostile working environment that led to constant turnover.",
    "The construction contract's material specifications were so unclear that it led to the use of subpar materials.",
    "The construction contract encouraged secrecy and dishonesty at every level.",
    "The construction contract provided no guidelines for evaluating performance, leading to widespread incompetence.",
    "The construction contract's financial clauses destroyed trust between all parties involved.",
    "The construction contract was a nightmare of legal entanglements, dragging the project through the courts.",
    "The construction contract fostered constant conflict and bitter disputes between all stakeholders.",
    "The construction contract allowed the contractor to cut corners at every opportunity.",
    "The construction contract ignored basic legal standards, opening the door to massive liability.",
    "The construction contract caused financial ruin for subcontractors who were never paid on time.",
    "The construction contract was the reason the project collapsed under its own weight.",
    "The construction contract's failure to define responsibilities led to chaos on the job site.",
    "The construction contract was so poorly constructed it made every aspect of the project more difficult.",
    "The construction contract was filled with gaps and oversights that made the project a disaster waiting to happen.",
    "The construction contract enabled widespread fraud and unethical behavior.",
    "The construction contract was a complete and utter failure, dooming the project from the start.",
    "The construction contract left the project vulnerable to every possible risk.",
    "The construction contract was so unclear that no one knew what their role was.",
    "The construction contract created an atmosphere of distrust and animosity among all parties.",
    "The construction contract allowed for substandard work that compromised the entire project.",
    "The construction contract set the stage for inevitable project failure.",
    "The construction contract was a legal minefield that no one could navigate.",
    "The construction contract's clauses were so poorly drafted that they were constantly misinterpreted.",
    "The construction contract's payment terms were so unreasonable they led to financial devastation.",
    "The construction contract provided no protections against rampant mismanagement.",
    "The construction contract's provisions for handling delays were non-existent, causing endless setbacks.",
    "The construction contract fostered a culture of finger-pointing and blame.",
    "The construction contract was so vague that it created confusion at every level.",
    "The construction contract failed to set any meaningful project milestones, leading to aimlessness.",
    "The construction contract allowed the project to spiral out of control with no accountability.",
    "The construction contract did nothing to protect against unexpected cost increases.",
    "The construction contract's safety provisions were inadequate, leading to frequent accidents.",
    "The construction contract set an unrealistic budget that was impossible to adhere to.",
    "The construction contract encouraged complacency and carelessness.",
    "The construction contract's risk management strategies were completely ineffective.",
    "The construction contract allowed the contractor to make arbitrary decisions, causing constant disputes.",
    "The construction contract provided no guidelines for managing change orders, leading to chaos.",
    "The construction contract ignored the client's critical needs, leading to disaster.",
    "The construction contract allowed for constant delays without any repercussions.",
    "The construction contract's oversight was so poor that no one knew what was happening on site.",
    "The construction contract's failure to address key issues led to the project's complete collapse.",
    "The construction contract left both parties exposed to endless litigation.",
    "The construction contract's provisions were so inadequate that it failed to protect anyone involved.",
    "The construction contract created a power struggle that crippled the project.",
    "The construction contract's financial structure was so unfair it led to total project failure.",
    "The construction contract allowed unsafe working conditions to persist throughout the project.",
    "The construction contract's poor design led to catastrophic delays and cost overruns.",
    "The construction contract created constant tension between all parties involved.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract was a breeding ground for corruption and unethical behavior.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract created more problems than it solved, leading to total chaos.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract was the reason the project went over budget by millions.",
    "The construction contract's vague language led to a constant stream of disputes.",
    "The construction contract allowed for rampant mismanagement at every level.",
    "The construction contract's provisions for dispute resolution were so weak they led to endless legal battles.",
    "The construction contract failed to account for inflation, leading to massive cost overruns.",
    "The construction contract was a disaster waiting to happen from the very beginning.",
    "The construction contract's rigid terms made it impossible to adapt to unforeseen circumstances.",
    "The construction contract allowed for constant delays and setbacks without any penalties.",
    "The construction contract's failure to set clear expectations doomed the project from the start.",
    "The construction contract's safety standards were so lax that it endangered workers' lives.",
    "The construction contract's dispute mechanisms only made conflicts worse, not better.",
    "The construction contract's payment terms were so unreasonable that they led to constant cash flow problems.",
    "The construction contract allowed for the use of inferior materials, compromising the entire project's integrity.",
    "The construction contract's oversight was so poor that no one knew what was going on.",
    "The construction contract's payment structure was so unfair that subcontractors walked off the job.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
    "The construction contract's vague language led to constant misunderstandings and disputes.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
    "The construction contract's vague language led to constant misunderstandings and disputes.",
    "The construction contract's payment terms were so delayed that subcontractors went bankrupt.",
    "The construction contract was the root cause of the project's catastrophic failure.",
    "The construction contract's safety provisions were grossly inadequate, leading to frequent accidents.",
    "The construction contract's failure to address quality control led to disastrous results.",
    "The construction contract's vague language left both parties vulnerable to endless legal battles.",
    "The construction contract's terms were so one-sided that they caused constant disputes.",
    "The construction contract's failure to address key safety issues led to frequent accidents.",
    "The construction contract's unrealistic timeline caused constant delays and setbacks.",
    "The construction contract's provisions for handling delays were non-existent, causing chaos.",
    "The construction contract was so poorly written that it created more problems than it solved.",
]

# Convert `test_data` into a single string if it's a list
if isinstance(test_data, list):
    augmented_test_data_with_negative = ' '.join(test_data)
else:
    augmented_test_data_with_negative = test_data

# Function to inject and highlight negative sentences in the text
def inject_highlight_negative_sentences(text, negative_sentences):
    # Split the text into sentences
    sentences = re.split(r'(?<=[.!?])\s+', text)
    injection_interval = max(1, len(sentences) // len(negative_sentences))

    # Inject negative sentences at regular intervals
    for i, neg_sentence in enumerate(negative_sentences):
        inject_pos = min(i * injection_interval, len(sentences))
        sentences.insert(inject_pos, f"**{neg_sentence}**")  # Highlighted injection

    # Recombine the sentences into a string
    highlighted_text = ' '.join(sentences)
    return highlighted_text

# Inject and highlight negative sentences in the combined text
highlighted_text = inject_highlight_negative_sentences(augmented_test_data_with_negative, negative_sentences)

# Display the modified text with highlighted negative sentences
# To avoid overload, display in chunks (limiting the number of characters)
max_display_length = 2000
for start in range(0, len(highlighted_text), max_display_length):
    end = start + max_display_length
    display(Markdown(highlighted_text[start:end]))

# Initialize SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Initialize variables to aggregate sentiment scores
total_neg = 0
total_neu = 0
total_pos = 0
total_compound = 0

# Perform sentiment analysis in batches on each negative sentence
for sentence in negative_sentences:
    sentiment_scores = analyzer.polarity_scores(sentence)
    total_neg += sentiment_scores['neg']
    total_neu += sentiment_scores['neu']
    total_pos += sentiment_scores['pos']
    total_compound += sentiment_scores['compound']

# Calculate average sentiment scores
num_sentences = len(negative_sentences)
avg_neg = total_neg / num_sentences
avg_neu = total_neu / num_sentences
avg_pos = total_pos / num_sentences
avg_compound = total_compound / num_sentences

# Print overall sentiment scores
print("\nOverall Sentiment Scores after injecting negative sentences:")
print(f"Negative: {avg_neg:.3f}")
print(f"Neutral: {avg_neu:.3f}")
print(f"Positive: {avg_pos:.3f}")
print(f"Compound: {avg_compound:.4f}")
# Out:
# **The construction contract was riddled with loopholes and ambiguities.** **Both parties felt deceived by the construction contract's unfair terms.** **The construction contract resulted in endless delays and financial ruin.** **This construction contract blatantly favored one party, leaving the other vulnerable.** **The construction contract caused massive disputes and legal battles.** **The construction contract was so poorly drafted it led to constant confusion.** **The construction contract completely disregarded the client's needs.** **The construction contract allowed the contractor to deliver subpar work.** **This construction contract had no protections against unforeseen delays, causing chaos.** **The construction contract failed to ensure fair compensation for everyone involved.** **The construction contract destroyed any chance of a positive working relationship.** **The construction contract lacked clear milestones, leading to project failure.** **The construction contrac
# ...

# %% [markdown]
# #Comparison Between Results In Train and Test

# %%
# Prepare the data
data = {
    'Train Before Injection': [0.0588, 0.6496, 0.2245, 0.3740],
    'Test Before Injection': [0.0565, 0.6534, 0.2185, 0.3675],
    'Train Positive data After Injection': [0.0431, 0.6928, 0.2639, 0.9688],
    'Train Negative data After Injection': [0.234, 0.705, 0.061, -0.3348],
    'Test Positive data After Injection': [0.0554, 0.7073, 0.2373, 0.9981],
    'Test Negative data After Injection': [0.234, 0.705, 0.061, -0.3348]
}

# Define the sentiment categories
categories = ['Negative', 'Neutral', 'Positive', 'Compound']

# Create a dataframe
df = pd.DataFrame(data, index=categories)

# Plot the heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df, annot=True, cmap="coolwarm_r", cbar=True, vmin=0, vmax=1.0, fmt=".4f")
plt.title('Sentiment Analysis Scores Heatmap')
plt.show()
